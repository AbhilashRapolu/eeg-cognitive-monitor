# %%
# !pip install mne
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# [notice] A new release of pip is available: 25.1.1 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: mne in c:\users\rapol\appdata\roaming\python\python313\site-packages (1.9.0)
# Requirement already satisfied: decorator in c:\users\rapol\appdata\roaming\python\python313\site-packages (from mne) (5.1.1)
# Requirement already satisfied: jinja2 in c:\users\rapol\appdata\roaming\python\python313\site-packages (from mne) (3.1.5)
# Requirement already satisfied: lazy-loader>=0.3 in c:\users\rapol\appdata\roaming\python\python313\site-packages (from mne) (0.4)
# Requirement already satisfied: matplotlib>=3.6 in c:\users\rapol\appdata\roaming\python\python313\site-packages (from mne) (3.10.0)
# Requirement already satisfied: numpy<3,>=1.23 in c:\users\rapol\appdata\roaming\python\python313\site-packages (from mne) (2.2.6)
# Requirement already satisfied: packaging in c:\users\rapol\appdata\roaming\python\python313\site-packages (from mne) (24.2)
# Requirement already satisfied: pooch>=1.5 in c:\users\rapol\appdata\roaming\python\python313\site-packages (from mne) (1.8.2)
# Requirement already satisfied: scipy>=1.9 in c:\users\rapol\appdata\roaming\python\python313\site-packages (from mne) (1.15.3)
# Requirement already satisfied: tqdm in c:\users\rapol\appdata\roaming\python\python313\site-packages (from mne) (4.67.1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\rapol\appdata\roaming\python\python313\site-packages (from matplotlib>=3.6->mne) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\rapol\appdata\roaming\python\python313\site-packages (from matplotlib>=3.6->mne) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\rapol\appdata\roaming\python\python313\site-packages (from matplotlib>=3.6->mne) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\rapol\appdata\roaming\python\python313\site-packages (from matplotlib>=3.6->mne) (1.4.8)
# Requirement already satisfied: pillow>=8 in c:\users\rapol\appdata\roaming\python\python313\site-packages (from matplotlib>=3.6->mne) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\rapol\appdata\roaming\python\python313\site-packages (from matplotlib>=3.6->mne) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\rapol\appdata\roaming\python\python313\site-packages (from matplotlib>=3.6->mne) (2.9.0.post0)
# Requirement already satisfied: platformdirs>=2.5.0 in c:\users\rapol\appdata\roaming\python\python313\site-packages (from pooch>=1.5->mne) (4.3.6)
# Requirement already satisfied: requests>=2.19.0 in c:\users\rapol\appdata\roaming\python\python313\site-packages (from pooch>=1.5->mne) (2.32.3)
# Requirement already satisfied: six>=1.5 in c:\users\rapol\appdata\roaming\python\python313\site-packages (from python-dateutil>=2.7->matplotlib>=3.6->mne) (1.17.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\rapol\appdata\roaming\python\python313\site-packages (from requests>=2.19.0->pooch>=1.5->mne) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\rapol\appdata\roaming\python\python313\site-packages (from requests>=2.19.0->pooch>=1.5->mne) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\rapol\appdata\roaming\python\python313\site-packages (from requests>=2.19.0->pooch>=1.5->mne) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\rapol\appdata\roaming\python\python313\site-packages (from requests>=2.19.0->pooch>=1.5->mne) (2024.12.14)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\rapol\appdata\roaming\python\python313\site-packages (from jinja2->mne) (3.0.2)
# Requirement already satisfied: colorama in c:\users\rapol\appdata\roaming\python\python313\site-packages (from tqdm->mne) (0.4.6)

# %%
#!/usr/bin/env python3
"""
Optimized 3-Channel Event-Locked Feature Extraction (FIXED)
- Voltage scaled to microvolts before feature extraction
- Fractal dimension normalized to prevent scale explosion
- Enhanced artifact rejection (amplitude + kurtosis + edge effects)
- Faster feature computation with vectorization
"""

import numpy as np
import pandas as pd
import mne
from pathlib import Path
from scipy.signal import detrend, welch, hilbert
from scipy.stats import entropy as scipy_entropy, kurtosis
from mne.filter import filter_data
import warnings
warnings.filterwarnings('ignore')

# === CONFIG ===
DATA_ROOT = Path(r"C:\Users\rapol\Downloads\manifold\subjects")
SAVE_DIR = Path(r"C:\Users\rapol\Downloads\eeg_features_3ch_event_locked_optimized")
SAVE_DIR.mkdir(parents=True, exist_ok=True)

SESSIONS = ["ses-S1", "ses-S2", "ses-S3"]
MUSE_CHANNELS = ['Fp1', 'Fp2', 'TP10']
BASELINE_WINDOW = (-0.5, 0.0)
TASK_WINDOW = (0.0, 2.0)
PERCENTILE = 95
KURTOSIS_THRESH = 5.0
EDGE_BUFFER = 0.5  # seconds

BANDS = {
    'delta': (0.5, 4),
    'theta': (4, 8),
    'alpha': (8, 13),
    'beta': (13, 30),
    'gamma': (30, 45)
}

DISCRETE_TASKS = [
    'zeroBACK','oneBACK','twoBACK',
    'PVT','Flanker',
    'RS_Beg_EO','RS_Beg_EC','RS_End_EO','RS_End_EC'
]
CONTINUOUS_TASKS = ['MATBeasy','MATBmed','MATBdiff']

TASK_MAPPINGS = {
    "zeroBACK":"nback_0","oneBACK":"nback_1","twoBACK":"nback_2",
    "MATBeasy":"matb_easy","MATBmed":"matb_med","MATBdiff":"matb_diff",
    "PVT":"pvt","Flanker":"flanker",
    "RS_Beg_EO":"rest_begin_open","RS_Beg_EC":"rest_begin_closed",
    "RS_End_EO":"rest_end_open","RS_End_EC":"rest_end_closed"
}

print(f"Output: {SAVE_DIR.resolve()}\n")

# === UTILITIES ===

def _autoscale(data):
    """Autoscale data already in microvolts."""
    m = np.median(np.abs(data))
    if m < 1.0:  # Already scaled to µV, just return
        return data, 1.0
    elif m < 1000.0:
        return data, 1.0
    return data, 1.0

def _artifact_reject(baseline_data, task_data, thresh_amp):
    """Multi-criterion artifact rejection."""
    if baseline_data.max() > thresh_amp or task_data.max() > thresh_amp:
        return True, "amplitude"
    
    k_base = kurtosis(baseline_data, axis=1).max()
    k_task = kurtosis(task_data, axis=1).max()
    if k_base > KURTOSIS_THRESH or k_task > KURTOSIS_THRESH:
        return True, "kurtosis"
    
    return False, "none"

# === FEATURE COMPUTATION ===

def compute_features_batch(baseline_data, task_data, sfreq):
    """Compute all features. Data assumed to be in µV."""
    features = {}
    
    # 1. Bandpowers
    nperseg_base = min(256, max(16, baseline_data.shape[1] // 2))
    nperseg_task = min(256, max(16, task_data.shape[1] // 2))
    
    freqs, psd_base = welch(baseline_data, fs=sfreq, nperseg=nperseg_base)
    freqs_task, psd_task = welch(task_data, fs=sfreq, nperseg=nperseg_task)
    
    for band_name, (lo, hi) in BANDS.items():
        mask = (freqs >= lo) & (freqs <= hi)
        features[f'baseline_bp_{band_name}'] = psd_base[:, mask].mean(axis=1)
        mask_task = (freqs_task >= lo) & (freqs_task <= hi)
        features[f'task_bp_{band_name}'] = psd_task[:, mask_task].mean(axis=1)
    
    # 2. Spectral entropy
    for data, pfx in [(baseline_data, 'baseline'), (task_data, 'task')]:
        ent = []
        for ch in data:
            ch_norm = (ch - ch.mean()) / (ch.std() + 1e-10)
            _, p = welch(ch_norm, nperseg=min(256, len(ch)//4))
            p /= p.sum() + 1e-12
            ent.append(scipy_entropy(p))
        features[f'{pfx}_entropy'] = np.array(ent)
    
    # 3. Band entropy
    for band_name, (lo, hi) in BANDS.items():
        filt_base = filter_data(baseline_data, sfreq, lo, hi, verbose=False)
        filt_task = filter_data(task_data, sfreq, lo, hi, verbose=False)
        
        be_base = []
        be_task = []
        for ch_b, ch_t in zip(filt_base, filt_task):
            _, p_b = welch(ch_b, fs=sfreq, nperseg=min(128, len(ch_b)//8))
            p_b /= p_b.sum() + 1e-10
            be_base.append(scipy_entropy(p_b))
            
            _, p_t = welch(ch_t, fs=sfreq, nperseg=min(128, len(ch_t)//8))
            p_t /= p_t.sum() + 1e-10
            be_task.append(scipy_entropy(p_t))
        
        features[f'baseline_be_{band_name}'] = np.array(be_base)
        features[f'task_be_{band_name}'] = np.array(be_task)
    
    # 4. Fractal & Hjorth (NORMALIZED to prevent scale explosion)
    for data, pfx in [(baseline_data, 'baseline'), (task_data, 'task')]:
        fract_hjorth = []
        for ch in data:
            ch_det = detrend(ch)
            # Normalize to unit variance BEFORE fractal computation
            ch_det = (ch_det - ch_det.mean()) / (ch_det.std() + 1e-10)
            
            # Higuchi FD
            lk = []
            for k in range(1, 6):
                lm = 0
                nmax = int((len(ch_det) - 1) / k)
                for m in range(k):
                    for j in range(1, nmax):
                        lm += abs(ch_det[m + j*k] - ch_det[m + (j-1)*k])
                lk.append(lm * (len(ch_det) - 1) / (nmax * k))
            
            x = np.log(1 / np.arange(1, 6))
            y = np.log(lk)
            higuchi_fd = -np.polyfit(x, y, 1)[0]
            
            # Katz FD
            l = np.sum(np.abs(np.diff(ch_det)))
            d = np.max(np.abs(ch_det - ch_det[0]))
            katz_fd = np.log10(l / d) / np.log10(l / (d + 1e-10)) if d > 0 else 1.0
            
            # Hjorth
            d1 = np.diff(ch_det)
            d2 = np.diff(d1) if len(d1) > 1 else np.array([0.0])
            v0 = np.var(ch_det)
            v1 = np.var(d1) if len(d1) > 0 else 0.0
            v2 = np.var(d2) if len(d2) > 0 else 0.0
            
            mob = np.sqrt(v1 / (v0 + 1e-10))
            comp = np.sqrt(v2 / (v1 + 1e-10)) / (mob + 1e-10)
            
            fract_hjorth.append([higuchi_fd, katz_fd, v0, mob, comp])
        
        features[f'{pfx}_fh'] = np.array(fract_hjorth)
    
    # 5. PLI connectivity
    for data, pfx in [(baseline_data, 'baseline'), (task_data, 'task')]:
        filt = filter_data(data, sfreq, 4, 30, verbose=False)
        analytic = np.array([hilbert(ch) for ch in filt])
        pli = []
        for i, j in [(0, 1), (0, 2), (1, 2)]:
            pd = np.angle(analytic[i]) - np.angle(analytic[j])
            pli.append(abs(np.mean(np.sign(np.imag(np.exp(1j * pd))))))
        features[f'{pfx}_pli'] = np.array(pli)
    
    return features

def flatten_features(feature_dict):
    """Flatten nested feature dict to 1D array."""
    flat = []
    for v in feature_dict.values():
        if isinstance(v, np.ndarray):
            flat.extend(v.flatten())
        else:
            flat.append(v)
    return np.array(flat, dtype=float)

# === EXTRACTION FUNCTIONS ===

def extract_discrete(raw, task, subject, session):
    """Extract event-locked features for discrete tasks."""
    sfreq = raw.info['sfreq']
    chn = raw.ch_names
    av = [c for c in MUSE_CHANNELS if c in chn]
    
    if len(av) < 3:
        return []
    
    raw.pick_channels(av)
    # FIXED: Scale to microvolts FIRST
    data = raw.get_data() * 1e6
    data, scale = _autoscale(data)
    thresh = np.percentile(np.abs(data), PERCENTILE)
    
    edge_samp = int(EDGE_BUFFER * sfreq)
    bs = int(abs(BASELINE_WINDOW[0]) * sfreq)
    ts = int(TASK_WINDOW[1] * sfreq)
    
    print(f"{subject} {session} {task} thresh={thresh:.1f}µV")
    
    try:
        ev, _ = mne.events_from_annotations(raw, verbose=False)
    except:
        return []
    
    out = []
    rej_counts = {'amplitude': 0, 'kurtosis': 0, 'edge': 0, 'boundary': 0}
    tot = 0
    
    for idx, e in enumerate(ev):
        tot += 1
        o = e[0]
        
        if o - bs < 0 or o + ts > data.shape[1]:
            rej_counts['boundary'] += 1
            continue
        
        if o - bs < edge_samp or o + ts > data.shape[1] - edge_samp:
            rej_counts['edge'] += 1
            continue
        
        bd = data[:, o-bs:o]
        td = data[:, o:o+ts]
        
        is_artifact, reason = _artifact_reject(bd, td, thresh)
        if is_artifact:
            rej_counts[reason] += 1
            continue
        
        try:
            feat_dict = compute_features_batch(bd, td, sfreq)
            feats_flat = flatten_features(feat_dict)
            
            rec = {
                'subject': subject,
                'session': session,
                'task': task,
                'trial_idx': idx,
                'event_code': int(e[2]),
                'onset_sample': o,
                'onset_time': o / sfreq
            }
            
            for i, v in enumerate(feats_flat):
                rec[f'f{i}'] = v
            
            out.append(rec)
        except Exception as ex:
            print(f"  Feature error trial {idx}: {ex}")
            continue
    
    if sum(rej_counts.values()) > 0:
        print(f"  Rejected: {rej_counts} ({sum(rej_counts.values())}/{tot})")
    
    return out

def extract_continuous(raw, task, subject, session):
    """Extract windowed features for continuous tasks."""
    sfreq = raw.info['sfreq']
    chn = raw.ch_names
    av = [c for c in MUSE_CHANNELS if c in chn]
    
    if len(av) < 3:
        return []
    
    raw.pick_channels(av)
    # FIXED: Scale to microvolts FIRST
    data = raw.get_data() * 1e6
    data, scale = _autoscale(data)
    thresh = np.percentile(np.abs(data), PERCENTILE)
    
    edge_samp = int(EDGE_BUFFER * sfreq)
    ws = int(2.0 * sfreq)
    ov = int(0.5 * sfreq)
    step = ws - ov
    
    print(f"{subject} {session} {task} thresh={thresh:.1f}µV")
    
    out = []
    rej_counts = {'amplitude': 0, 'kurtosis': 0, 'edge': 0}
    tot = 0
    
    nw = (data.shape[1] - ws) // step + 1
    for w in range(nw):
        tot += 1
        s = w * step
        e = s + ws
        
        if e > data.shape[1]:
            break
        
        if s < edge_samp or e > data.shape[1] - edge_samp:
            rej_counts['edge'] += 1
            continue
        
        wd = data[:, s:e]
        
        is_artifact, reason = _artifact_reject(wd, wd, thresh)
        if is_artifact:
            rej_counts[reason] += 1
            continue
        
        try:
            mid = wd.shape[1] // 2
            feat_dict = compute_features_batch(wd[:, :mid], wd[:, mid:], sfreq)
            feats_flat = flatten_features(feat_dict)
            
            rec = {
                'subject': subject,
                'session': session,
                'task': task,
                'trial_idx': w,
                'event_code': -1,
                'onset_sample': s,
                'onset_time': s / sfreq
            }
            
            for i, v in enumerate(feats_flat):
                rec[f'f{i}'] = v
            
            out.append(rec)
        except Exception as ex:
            print(f"  Feature error window {w}: {ex}")
            continue
    
    if sum(rej_counts.values()) > 0:
        print(f"  Rejected: {rej_counts} ({sum(rej_counts.values())}/{tot})")
    
    return out

def process_session(subject, session):
    """Process all tasks for one subject-session."""
    eeg_dir = DATA_ROOT / subject / subject / session / "eeg"
    
    if not eeg_dir.exists():
        return None
    
    all_recs = []
    
    for fn, task in TASK_MAPPINGS.items():
        sf = eeg_dir / f"{fn}.set"
        if not sf.exists():
            continue
        
        try:
            raw = mne.io.read_raw_eeglab(str(sf), preload=True, verbose=False)
            
            if fn in DISCRETE_TASKS:
                recs = extract_discrete(raw, task, subject, session)
            else:
                recs = extract_continuous(raw, task, subject, session)
            
            all_recs.extend(recs)
            print(f"  {fn:15s}: {len(recs):4d}")
        except Exception as ex:
            print(f"  {fn:15s}: ERROR - {ex}")
            continue
    
    if all_recs:
        out_file = SAVE_DIR / f"{subject}_{session}_trials_event_locked.csv"
        pd.DataFrame(all_recs).to_csv(out_file, index=False)
        print(f"✓ {subject} {session}: {len(all_recs)} trials → {out_file.name}")
        return (subject, session, len(all_recs))
    
    return None

def main():
    job_queue = []
    for i in range(1, 22):
        subj = f"sub-{i:02d}"
        for sess in SESSIONS:
            job_queue.append((subj, sess))
    
    print(f"Processing {len(job_queue)} subject-session pairs...\n")
    
    results = []
    for i, (subject, session) in enumerate(job_queue, start=1):
        print(f"\n[{i}/{len(job_queue)}] {subject} {session}")
        result = process_session(subject, session)
        if result:
            results.append(result)
    
    results = [r for r in results if r is not None]
    
    print("\n" + "="*80)
    print(f"EXTRACTION COMPLETE: {len(results)} sessions processed")
    print(f"Total trials: {sum(r[2] for r in results)}")
    print(f"Output: {SAVE_DIR.resolve()}")
    print("="*80)

if __name__ == "__main__":
    main()
# Out:
# Output: C:\Users\rapol\Downloads\eeg_features_3ch_event_locked_optimized
#
# Processing 63 subject-session pairs...
#
#
# [1/63] sub-01 ses-S1
# sub-01 ses-S1 nback_0 thresh=12529.0µV
#   Rejected: {'amplitude': 0, 'kurtosis': 2, 'edge': 0, 'boundary': 3} (5/203)
#   zeroBACK       :  198
# sub-01 ses-S1 nback_1 thresh=14366.3µV
#   Rejected: {'amplitude': 0, 'kurtosis': 0, 'edge': 0, 'boundary': 2} (2/198)
#   oneBACK        :  196
# sub-01 ses-S1 nback_2 thresh=14255.9µV
#   Rejected: {'amplitude': 0, 'kurtosis': 7, 'edge': 0, 'boundary': 3} (10/208)
#   twoBACK        :  198
# sub-01 ses-S1 matb_easy thresh=14503.6µV
#   Rejected: {'amplitude': 0, 'kurtosis': 0, 'edge': 2} (2/199)
#   MATBeasy       :  197
# sub-01 ses-S1 matb_med thresh=12209.6µV
#   Rejected: {'amplitude': 0, 'kurtosis': 0, 'edge': 2} (2/199)
#   MATBmed        :  197
# sub-01 ses-S1 matb_diff thresh=10558.0µV
#   Rejected: {'amplitude': 0, 'kurtosis': 2, 'edge': 2} (4/199)
#   MATBdiff       :  195
# sub-01 ses-S1 pvt thresh=13481.3µV
#   Rejected: {'amplitude': 0, 'kurtosis': 9, 'edge': 0, 'boundary': 4} (13/272)
#   PVT            :  259
# sub-01 ses-S1 flanker thresh=11891.7µV
#   Rejected: {'amplitude': 0, 'kurtosis': 12, 'edge': 0, 'boundary': 5} (17/483)
#   Flanker        :  466
# sub-01 ses-S1 rest_begin_open thresh=14583.9µV
#   Rejected: {'amplitude': 0, 'kurtosis': 0, 'edge': 0, 'boundary': 2} (2/2)
#   RS_Beg_EO      :    0
# sub-01 ses-S1 rest_begin_closed thresh=14494.4µV
#   Rejected: {'amplitude': 0, 'kurtosis': 0, 'edge': 0, 'boundary': 2} (2/2)
#   RS_Beg_EC      :    0
# sub-01 ses-S1 rest_end_open thresh=10392.8µV
#   Rejected: {'amplitude': 0, 'kurtosis': 0, 'edge': 0, 'boundary': 2} (2/2)
#   RS_End_EO      :    0
# sub-01 ses-S1 rest_end_closed thresh=10536.6µV
#   Rejected: {'amplitude': 0, 'kurtosis': 0, 'edge': 0, 'boundary': 2} (2/2)
#   RS_End_EC      :    0
# ✓ sub-01 ses-S1: 1906 trials → sub-01_ses-S1_trials_event_locked.csv
#
# [2/63] sub-01 ses-S2
# sub-01 ses-S2 nback_0 thresh=3912.5µV
#   Rejected: {'amplitude': 0, 'kurtosis': 0, 'edge': 0, 'boundary': 3} (3/205)
#   zeroBACK       :  202
# sub-01 ses-S2 nback_1 thresh=4685.0µV
#   Rejected: {'amplitude': 0, 'kurtosis': 0, 'edge': 0, 'boundary': 2} (2/202)
#   oneBACK        :  200
# sub-01 ses-S2 nback_2 thresh=5144.6µV
#   Rejected: {'amplitude': 56, 'kurtosis': 0, 'edge': 0, 'boundary': 3} (59/209)
#   twoBACK        :  150
# sub-01 ses-S2 matb_easy thresh=6197.9µV
#   Rejected: {'amplitude': 51, 'kurtosis': 0, 'edge': 2} (53/199)
#   MATBeasy       :  146
# sub-01 ses-S2 matb_med thresh=3162.2µV
#   Rejected: {'amplitude': 0, 'kurtosis': 0, 'edge': 2} (2/199)
#   MATBmed        :  197
# sub-01 ses-S2 matb_diff thresh=6928.9µV
#   Rejected: {'amplitude': 66, 'kurtosis': 0, 'edge': 2} (68/199)
#   MATBdiff       :  131
# sub-01 ses-S2 pvt thresh=5354.0µV
#   Rejected: {'amplitude': 130, 'kurtosis': 0, 'edge': 0, 'boundary': 4} (134/273)
#   PVT            :  139
# sub-01 ses-S2 flanker thresh=3724.9µV
#   Rejected: {'amplitude': 0, 'kurtosis': 0, 'edge': 1, 'boundary': 5} (6/482)
#   Flanker        :  476
# sub-01 ses-S2 rest_begin_open thresh=7151.6µV
#   Rejected: {'amplitude': 0, 'kurtosis': 0, 'edge': 0, 'boundary': 2} (2/2)
#   RS_Beg_EO      :    0
# sub-01 ses-S2 rest_begin_closed thresh=7041.3µV
#   Rejected: {'amplitude': 0, 'kurtosis': 0, 'edge': 0, 'boundary': 2} (2/2)
#   RS_Beg_EC      :    0
# sub-01 ses-S2 rest_end_open thresh=2941.9µV
#   Rejected: {'amplitude': 0, 'kurtosis': 0, 'edge': 0, 'boundary': 2} (2/2)
#   RS_End_EO      :    0
# sub-01 ses-S2 rest_end_closed thresh=3119.3µV
#   Rejected: {'amplitude': 0, 'kurtosis': 0, 'edge': 0, 'boundary': 2} (2/2)
#   RS_End_EC      :    0
# ✓ sub-01 ses-S2: 1641 trials → sub-01_ses-S2_trials_event_locked.csv
#
# [3/63] sub-01 ses-S3
# sub-01 ses-S3 nback_0 thresh=29648.0µV
#   Rejected: {'amplitude': 0, 'kurtosis': 0, 'edge': 0, 'boundary': 3} (3/203)
#   zeroBACK       :  200
# sub-01 ses-S3 nback_1 thresh=26968.3µV
#   Rejected: {'amplitude': 0, 'kurtosis': 2, 'edge': 1, 'boundary': 3} (6/199)
#   oneBACK        :  193
# sub-01 ses-S3 nback_2 thresh=29675.4µV
#   Rejected: {'amplitude': 0, 'kurtosis': 0, 'edge': 1, 'boundary': 3} (4/211)
#   twoBACK        :  207
# sub-01 ses-S3 matb_easy thresh=28155.2µV
#   Rejected: {'amplitude': 0, 'kurtosis': 0, 'edge': 2} (2/199)
#   MATBeasy       :  197
# sub-01 ses-S3 matb_med thresh=26871.3µV
#   Rejected: {'amplitude': 0, 'kurtosis': 0, 'edge': 1} (1/199)
#   MATBmed        :  198
# sub-01 ses-S3 matb_diff thresh=27720.6µV
#   Rejected: {'amplitude': 0, 'kurtosis': 0, 'edge': 2} (2/199)
#   MATBdiff       :  197
# sub-01 ses-S3 pvt thresh=27290.4µV
#   Rejected: {'amplitude': 0, 'kurtosis': 3, 'edge': 0, 'boundary': 4} (7/273)
#   PVT            :  266
# sub-01 ses-S3 flanker thresh=28984.6µV
#   Rejected: {'amplitude': 0, 'kurtosis': 1, 'edge': 1, 'boundary': 5} (7/483)
#   Flanker        :  476
# sub-01 ses-S3 rest_begin_open thresh=28435.9µV
#   Rejected: {'amplitude': 0, 'kurtosis': 0, 'edge': 0, 'boundary': 2} (2/2)
#   RS_Beg_EO      :    0
# sub-01 ses-S3 rest_begin_closed thresh=29045.6µV
#   Rejected: {'amplitude': 0, 'kurtosis': 0, 'edge': 0, 'boundary': 2} (2/2)
#   RS_Beg_EC      :    0
# sub-01 ses-S3 rest_end_open thresh=26867.1µV
#   Rejected: {'amplitude': 0, 'kurtosis': 0, 'edge': 0, 'boundary': 2} (2/2)
#   RS_End_EO      :    0
# sub-01 ses-S3 rest_end_closed thresh=26994.9µV
#   Rejected: {'amplitude': 0, 'kurtosis': 0, 'edge': 0, 'boundary': 2} (2/2)
#   RS_End_EC      :    0
# ✓ sub-01 ses-S3: 1934 trials → sub-01_ses-S3_trials_event_locked.csv
#
# [4/63] sub-02 ses-S1
# sub-02 ses-S1 nback_0 thresh=21194.5µV
#   Rejected: {'amplitude': 184, 'kurtosis': 0, 'edge': 0, 'boundary': 3} (187/204)
#   zeroBACK       :   17
# sub-02 ses-S1 nback_1 thresh=21617.4µV
#   Rejected: {'amplitude': 81, 'kurtosis': 0, 'edge': 0, 'boundary': 3} (84/199)
#   oneBACK        :  115
# sub-02 ses-S1 nback_2 thresh=21297.1µV
#   Rejected: {'amplitude': 119, 'kurtosis': 0, 'edge': 0, 'boundary': 3} (122/209)
#   twoBACK        :   87
# sub-02 ses-S1 matb_easy thresh=21571.0µV
#   Rejected: {'amplitude': 91, 'kurtosis': 0, 'edge': 2} (93/199)
#   MATBeasy       :  106
# sub-02 ses-S1 matb_med thresh=21435.4µV
#   Rejected: {'amplitude': 147, 'kurtosis': 0, 'edge': 2} (149/199)
#   MATBmed        :   50
# sub-02 ses-S1 matb_diff thresh=21972.6µV
#   Rejected: {'amplitude': 101, 'kurtosis': 0, 'edge': 2} (103/199)
#   MATBdiff       :   96
# sub-02 ses-S1 pvt thresh=22075.3µV
#   Rejected: {'amplitude': 143, 'kurtosis': 1, 'edge': 0, 'boundary': 4} (148/272)
#   PVT            :  124
# sub-02 ses-S1 flanker thresh=21607.1µV
#   Rejected: {'amplitude': 355, 'kurtosis': 0, 'edge': 1, 'boundary': 5} (361/483)
#   Flanker        :  122
# sub-02 ses-S1 rest_begin_open thresh=20866.8µV
#   Rejected: {'amplitude': 0, 'kurtosis': 0, 'edge': 0, 'boundary': 2} (2/2)
#   RS_Beg_EO      :    0
# sub-02 ses-S1 rest_begin_closed thresh=20826.8µV
#   Rejected: {'amplitude': 0, 'kurtosis': 0, 'edge': 0, 'boundary': 2} (2/2)
#   RS_Beg_EC      :    0
# sub-02 ses-S1 rest_end_open thresh=22208.6µV
#   Rejected: {'amplitude': 0, 'kurtosis': 0, 'edge': 0, 'boundary': 2} (2/2)
#   RS_End_EO      :    0
# sub-02 ses-S1 rest_end_closed thresh=22171.7µV
#   Rejected: {'amplitude': 0, 'kurtosis': 0, 'edge': 0, 'boundary': 2} (2/2)
#   RS_End_EC      :    0
# ✓ sub-02 ses-S1: 717 trials → sub-02_ses-S1_trials_event_locked.csv
#
# [5/63] sub-02 ses-S2
# sub-02 ses-S2 nback_0 thresh=11350.7µV
#   Rejected: {'amplitude': 0, 'kurtosis': 46, 'edge': 0, 'boundary': 3} (49/204)
#   zeroBACK       :  155
# sub-02 ses-S2 nback_1 thresh=11101.9µV
#   Rejected: {'amplitude': 0, 'kurtosis': 10, 'edge': 0, 'boundary': 3} (13/202)
#   oneBACK        :  189
# sub-02 ses-S2 nback_2 thresh=10690.2µV
#   Rejected: {'amplitude': 0, 'kurtosis': 11, 'edge': 2, 'boundary': 3} (16/213)
#   twoBACK        :  197
# sub-02 ses-S2 matb_easy thresh=10152.1µV
#   Rejected: {'amplitude': 0, 'kurtosis': 20, 'edge': 2} (22/199)
#   MATBeasy       :  177
# sub-02 ses-S2 matb_med thresh=11536.7µV
#   Rejected: {'amplitude': 0, 'kurtosis': 15, 'edge': 2} (17/199)
#   MATBmed        :  182
# sub-02 ses-S2 matb_diff thresh=10950.0µV
#   Rejected: {'amplitude': 0, 'kurtosis': 18, 'edge': 2} (20/199)
#   MATBdiff       :  179
# sub-02 ses-S2 pvt thresh=11385.9µV
#   Rejected: {'amplitude': 0, 'kurtosis': 18, 'edge': 0, 'boundary': 4} (22/273)
#   PVT            :  251
# sub-02 ses-S2 flanker thresh=11386.1µV
#   Rejected: {'amplitude': 0, 'kurtosis': 80, 'edge': 1, 'boundary': 5} (86/483)
#   Flanker        :  397
# sub-02 ses-S2 rest_begin_open thresh=9448.8µV
#   Rejected: {'amplitude': 0, 'kurtosis': 0, 'edge': 0, 'boundary': 2} (2/2)
#   RS_Beg_EO      :    0
# sub-02 ses-S2 rest_begin_closed thresh=9554.8µV
#   Rejected: {'amplitude': 0, 'kurtosis': 0, 'edge': 0, 'boundary': 2} (2/2)
#   RS_Beg_EC      :    0
# sub-02 ses-S2 rest_end_open thresh=11290.4µV
#   Rejected: {'amplitude': 0, 'kurtosis': 0, 'edge': 0, 'boundary': 2} (2/2)
#   RS_End_EO      :    0
# sub-02 ses-S2 rest_end_closed thresh=11311.4µV
#   Rejected: {'amplitude': 0, 'kurtosis': 0, 'edge': 0, 'boundary': 2} (2/2)
#   RS_End_EC      :    0
# ✓ sub-02 ses-S2: 1727 trials → sub-02_ses-S2_trials_event_locked.csv
#
# [6/63] sub-02 ses-S3
# sub-02 ses-S3 nback_0 thresh=5785.8µV
#   Rejected: {'amplitude': 0, 'kurtosis': 33, 'edge': 1, 'boundary': 3} (37/204)
#   zeroBACK       :  167
# sub-02 ses-S3 nback_1 thresh=6211.1µV
#   Rejected: {'amplitude': 0, 'kurtosis': 57, 'edge': 0, 'boundary': 3} (60/203)
#   oneBACK        :  143
# sub-02 ses-S3 nback_2 thresh=5741.0µV
#   Rejected: {'amplitude': 0, 'kurtosis': 27, 'edge': 0, 'boundary': 3} (30/210)
#   twoBACK        :  180
# sub-02 ses-S3 matb_easy thresh=5839.0µV
#   Rejected: {'amplitude': 0, 'kurtosis': 66, 'edge': 2} (68/199)
#   MATBeasy       :  131
# sub-02 ses-S3 matb_med thresh=5378.8µV
#   Rejected: {'amplitude': 0, 'kurtosis': 30, 'edge': 2} (32/199)
#   MATBmed        :  167
# sub-02 ses-S3 matb_diff thresh=5823.4µV
#   Rejected: {'amplitude': 0, 'kurtosis': 36, 'edge': 2} (38/199)
#   MATBdiff       :  161
# sub-02 ses-S3 pvt thresh=5490.1µV
#   Rejected: {'amplitude': 0, 'kurtosis': 56, 'edge': 0, 'boundary': 4} (60/272)
#   PVT            :  212
# sub-02 ses-S3 flanker thresh=6266.2µV
#   Rejected: {'amplitude': 0, 'kurtosis': 171, 'edge': 0, 'boundary': 5} (176/482)
#   Flanker        :  306
# sub-02 ses-S3 rest_begin_open thresh=6129.9µV
#   Rejected: {'amplitude': 0, 'kurtosis': 0, 'edge': 0, 'boundary': 2} (2/2)
#   RS_Beg_EO      :    0
# sub-02 ses-S3 rest_begin_closed thresh=6013.1µV
#   Rejected: {'amplitude': 0, 'kurtosis': 0, 'edge': 0, 'boundary': 2} (2/2)
#   RS_Beg_EC      :    0
# sub-02 ses-S3 rest_end_open thresh=6192.2µV
#   Rejected: {'amplitude': 0, 'kurtosis': 0, 'edge': 0, 'boundary': 2} (2/2)
#   RS_End_EO      :    0
# sub-02 ses-S3 rest_end_closed thresh=6238.5µV
#   Rejected: {'amplitude': 0, 'kurtosis': 0, 'edge': 0, 'boundary': 2} (2/2)
#   RS_End_EC      :    0
# ✓ sub-02 ses-S3: 1467 trials → sub-02_ses-S3_trials_event_locked.csv
#
# [7/63] sub-03 ses-S1
# sub-03 ses-S1 nback_0 thresh=14695.3µV
#   Rejected: {'amplitude': 45, 'kurtosis': 0, 'edge': 1, 'boundary': 2} (48/203)
#   zeroBACK       :  155
# sub-03 ses-S1 nback_1 thresh=11696.2µV
#   Rejected: {'amplitude': 52, 'kurtosis': 0, 'edge': 0, 'boundary': 3} (55/201)
#   oneBACK        :  146
# sub-03 ses-S1 nback_2 thresh=11193.7µV
#   Rejected: {'amplitude': 67, 'kurtosis': 0, 'edge': 0, 'boundary': 3} (70/211)
#   twoBACK        :  141
# sub-03 ses-S1 matb_easy thresh=9998.0µV
#   Rejected: {'amplitude': 68, 'kurtosis': 0, 'edge': 2} (70/199)
#   MATBeasy       :  129
# sub-03 ses-S1 matb_med thresh=10687.3µV
#   Rejected: {'amplitude': 81, 'kurtosis': 0, 'edge': 2} (83/199)
#   MATBmed        :  116
# sub-03 ses-S1 matb_diff thresh=12155.0µV
#   Rejected: {'amplitude': 113, 'kurtosis': 0, 'edge': 2} (115/199)
#   MATBdiff       :   84
# sub-03 ses-S1 pvt thresh=13515.9µV
#   Rejected: {'amplitude': 51, 'kurtosis': 0, 'edge': 0, 'boundary': 4} (55/272)
#   PVT            :  217
# sub-03 ses-S1 flanker thresh=10315.8µV
#   Rejected: {'amplitude': 236, 'kurtosis': 0, 'edge': 0, 'boundary': 6} (242/483)
#   Flanker        :  241
# sub-03 ses-S1 rest_begin_open thresh=15536.5µV
#   Rejected: {'amplitude': 0, 'kurtosis': 0, 'edge': 0, 'boundary': 2} (2/2)
#   RS_Beg_EO      :    0
# sub-03 ses-S1 rest_begin_closed thresh=15097.2µV
#   Rejected: {'amplitude': 0, 'kurtosis': 0, 'edge': 0, 'boundary': 2} (2/2)
#   RS_Beg_EC      :    0
# sub-03 ses-S1 rest_end_open thresh=9774.2µV
#   Rejected: {'amplitude': 0, 'kurtosis': 0, 'edge': 0, 'boundary': 2} (2/2)
#   RS_End_EO      :    0
# sub-03 ses-S1 rest_end_closed thresh=9484.6µV
#   Rejected: {'amplitude': 0, 'kurtosis': 0, 'edge': 0, 'boundary': 2} (2/2)
#   RS_End_EC      :    0
# ✓ sub-03 ses-S1: 1229 trials → sub-03_ses-S1_trials_event_locked.csv
#
# [8/63] sub-03 ses-S2
# sub-03 ses-S2 nback_0 thresh=13330.4µV
#   Rejected: {'amplitude': 69, 'kurtosis': 0, 'edge': 0, 'boundary': 3} (72/204)
#   zeroBACK       :  132
# sub-03 ses-S2 nback_1 thresh=13745.7µV
#   Rejected: {'amplitude': 88, 'kurtosis': 0, 'edge': 0, 'boundary': 3} (91/200)
#   oneBACK        :  109
# sub-03 ses-S2 nback_2 thresh=13585.1µV
#   Rejected: {'amplitude': 69, 'kurtosis': 0, 'edge': 0, 'boundary': 3} (72/209)
#   twoBACK        :  137
# sub-03 ses-S2 matb_easy thresh=13632.2µV
#   Rejected: {'amplitude': 95, 'kurtosis': 0, 'edge': 2} (97/199)
#   MATBeasy       :  102
# sub-03 ses-S2 matb_med thresh=12164.2µV
#   Rejected: {'amplitude': 44, 'kurtosis': 0, 'edge': 2} (46/199)
#   MATBmed        :  153
# sub-03 ses-S2 matb_diff thresh=14425.6µV
#   Rejected: {'amplitude': 102, 'kurtosis': 0, 'edge': 1} (103/199)
#   MATBdiff       :   96
# sub-03 ses-S2 pvt thresh=12628.6µV
#   Rejected: {'amplitude': 67, 'kurtosis': 0, 'edge': 0, 'boundary': 4} (71/272)
#   PVT            :  201
# sub-03 ses-S2 flanker thresh=14225.8µV
#   Rejected: {'amplitude': 99, 'kurtosis': 0, 'edge': 0, 'boundary': 5} (104/483)
#   Flanker        :  379
# sub-03 ses-S2 rest_begin_open thresh=9159.4µV
#   Rejected: {'amplitude': 0, 'kurtosis': 0, 'edge': 0, 'boundary': 2} (2/2)
#   RS_Beg_EO      :    0
# sub-03 ses-S2 rest_begin_closed thresh=9873.3µV
#   Rejected: {'amplitude': 0, 'kurtosis': 0, 'edge': 0, 'boundary': 2} (2/2)
#   RS_Beg_EC      :    0
# sub-03 ses-S2 rest_end_open thresh=12285.7µV
#   Rejected: {'amplitude': 0, 'kurtosis': 0, 'edge': 0, 'boundary': 2} (2/2)
#   RS_End_EO      :    0
# sub-03 ses-S2 rest_end_closed thresh=12107.2µV
#   Rejected: {'amplitude': 0, 'kurtosis': 0, 'edge': 0, 'boundary': 2} (2/2)
#   RS_End_EC      :    0
# ✓ sub-03 ses-S2: 1309 trials → sub-03_ses-S2_trials_event_locked.csv
#
# [9/63] sub-03 ses-S3
# sub-03 ses-S3 nback_0 thresh=25756.7µV
#   Rejected: {'amplitude': 0, 'kurtosis': 0, 'edge': 0, 'boundary': 3} (3/204)
#   zeroBACK       :  201
# sub-03 ses-S3 nback_1 thresh=26450.6µV
#   Rejected: {'amplitude': 0, 'kurtosis': 0, 'edge': 1, 'boundary': 3} (4/201)
#   oneBACK        :  197
# sub-03 ses-S3 nback_2 thresh=25291.4µV
#   Rejected: {'amplitude': 0, 'kurtosis': 1, 'edge': 0, 'boundary': 3} (4/210)
#   twoBACK        :  206
# sub-03 ses-S3 matb_easy thresh=26093.1µV
#   Rejected: {'amplitude': 0, 'kurtosis': 0, 'edge': 2} (2/199)
#   MATBeasy       :  197
# sub-03 ses-S3 matb_med thresh=27116.9µV
#   Rejected: {'amplitude': 0, 'kurtosis': 0, 'edge': 2} (2/199)
#   MATBmed        :  197
# sub-03 ses-S3 matb_diff thresh=22829.4µV
#   Rejected: {'amplitude': 0, 'kurtosis': 0, 'edge': 2} (2/199)
#   MATBdiff       :  197
# sub-03 ses-S3 pvt thresh=22139.5µV
#   Rejected: {'amplitude': 0, 'kurtosis': 0, 'edge': 0, 'boundary': 4} (4/272)
#   PVT            :  268
# sub-03 ses-S3 flanker thresh=24606.7µV
#   Rejected: {'amplitude': 0, 'kurtosis': 0, 'edge': 1, 'boundary': 5} (6/483)
#   Flanker        :  477
# sub-03 ses-S3 rest_begin_open thresh=26989.1µV
#   Rejected: {'amplitude': 0, 'kurtosis': 0, 'edge': 0, 'boundary': 2} (2/2)
#   RS_Beg_EO      :    0
# sub-03 ses-S3 rest_begin_closed thresh=27371.7µV
#   Rejected: {'amplitude': 0, 'kurtosis': 0, 'edge': 0, 'boundary': 2} (2/2)
#   RS_Beg_EC      :    0
# sub-03 ses-S3 rest_end_open thresh=21016.4µV
#   Rejected: {'amplitude': 0, 'kurtosis': 0, 'edge': 0, 'boundary': 2} (2/2)
#   RS_End_EO      :    0
# sub-03 ses-S3 rest_end_closed thresh=20957.9µV
#   Rejected: {'amplitude': 0, 'kurtosis': 0, 'edge': 0, 'boundary': 2} (2/2)
#   RS_End_EC      :    0
# ✓ sub-03 ses-S3: 1940 trials → sub-03_ses-S3_trials_event_locked.csv
#
# [10/63] sub-04 ses-S1
# sub-04 ses-S1 nback_0 thresh=4914.5µV
#   Rejected: {'amplitude': 96, 'kurtosis': 0, 'edge': 0, 'boundary': 3} (99/205)
#   zeroBACK       :  106
# sub-04 ses-S1 nback_1 thresh=3775.3µV
#   Rejected: {'amplitude': 131, 'kurtosis': 0, 'edge': 0, 'boundary': 3} (134/199)
#   oneBACK        :   65
# sub-04 ses-S1 nback_2 thresh=5440.8µV
#   Rejected: {'amplitude': 68, 'kurtosis': 0, 'edge': 0, 'boundary': 3} (71/205)
#   twoBACK        :  134
# sub-04 ses-S1 matb_easy thresh=6506.6µV
#   Rejected: {'amplitude': 94, 'kurtosis': 0, 'edge': 1} (95/199)
#   MATBeasy       :  104
# sub-04 ses-S1 matb_med thresh=7418.4µV
#   Rejected: {'amplitude': 69, 'kurtosis': 0, 'edge': 2} (71/199)
#   MATBmed        :  128
# sub-04 ses-S1 matb_diff thresh=5956.7µV
#   Rejected: {'amplitude': 110, 'kurtosis': 0, 'edge': 2} (112/199)
#   MATBdiff       :   87
# sub-04 ses-S1 pvt thresh=9142.6µV
#   Rejected: {'amplitude': 72, 'kurtosis': 0, 'edge': 0, 'boundary': 4} (76/273)
#   PVT            :  197
# sub-04 ses-S1 flanker thresh=4112.2µV
#   Rejected: {'amplitude': 222, 'kurtosis': 0, 'edge': 0, 'boundary': 6} (228/483)
#   Flanker        :  255
# sub-04 ses-S1 rest_begin_open thresh=9549.0µV
#   Rejected: {'amplitude': 0, 'kurtosis': 0, 'edge': 0, 'boundary': 2} (2/2)
#   RS_Beg_EO      :    0
# sub-04 ses-S1 rest_begin_closed thresh=9397.7µV
#   Rejected: {'amplitude': 0, 'kurtosis': 0, 'edge': 0, 'boundary': 2} (2/2)
#   RS_Beg_EC      :    0
# sub-04 ses-S1 rest_end_open thresh=3463.7µV
#   Rejected: {'amplitude': 0, 'kurtosis': 0, 'edge': 0, 'boundary': 2} (2/2)
#   RS_End_EO      :    0
# sub-04 ses-S1 rest_end_closed thresh=3309.5µV
#   Rejected: {'amplitude': 0, 'kurtosis': 0, 'edge': 0, 'boundary': 2} (2/2)
#   RS_End_EC      :    0
# ✓ sub-04 ses-S1: 1076 trials → sub-04_ses-S1_trials_event_locked.csv
#
# [11/63] sub-04 ses-S2
# sub-04 ses-S2 nback_0 thresh=9461.9µV
#   Rejected: {'amplitude': 0, 'kurtosis': 4, 'edge': 0, 'boundary': 3} (7/203)
#   zeroBACK       :  196
# sub-04 ses-S2 nback_1 thresh=9655.3µV
#   Rejected: {'amplitude': 0, 'kurtosis': 11, 'edge': 0, 'boundary': 3} (14/200)
#   oneBACK        :  186
# sub-04 ses-S2 nback_2 thresh=9572.4µV
#   Rejected: {'amplitude': 0, 'kurtosis': 7, 'edge': 0, 'boundary': 3} (10/209)
#   twoBACK        :  199
# sub-04 ses-S2 matb_easy thresh=9541.6µV
#   Rejected: {'amplitude': 0, 'kurtosis': 0, 'edge': 2} (2/199)
#   MATBeasy       :  197
# sub-04 ses-S2 matb_med thresh=9623.5µV
#   Rejected: {'amplitude': 0, 'kurtosis': 1, 'edge': 2} (3/199)
#   MATBmed        :  196
# sub-04 ses-S2 matb_diff thresh=9609.7µV
#   Rejected: {'amplitude': 0, 'kurtosis': 0, 'edge': 2} (2/199)
#   MATBdiff       :  197
# sub-04 ses-S2 pvt thresh=9147.9µV
#   Rejected: {'amplitude': 0, 'kurtosis': 0, 'edge': 0, 'boundary': 4} (4/272)
#   PVT            :  268
# sub-04 ses-S2 flanker thresh=9295.6µV
#   Rejected: {'amplitude': 0, 'kurtosis': 51, 'edge': 1, 'boundary': 5} (57/483)
#   Flanker        :  426
# sub-04 ses-S2 rest_begin_open thresh=8782.1µV
#   Rejected: {'amplitude': 0, 'kurtosis': 0, 'edge': 0, 'boundary': 2} (2/2)
#   RS_Beg_EO      :    0
# sub-04 ses-S2 rest_begin_closed thresh=8841.5µV
#   Rejected: {'amplitude': 0, 'kurtosis': 0, 'edge': 0, 'boundary': 2} (2/2)
#   RS_Beg_EC      :    0
# sub-04 ses-S2 rest_end_open thresh=9623.7µV
#   Rejected: {'amplitude': 0, 'kurtosis': 0, 'edge': 0, 'boundary': 2} (2/2)
#   RS_End_EO      :    0
# sub-04 ses-S2 rest_end_closed thresh=9599.3µV
#   Rejected: {'amplitude': 0, 'kurtosis': 0, 'edge': 0, 'boundary': 2} (2/2)
#   RS_End_EC      :    0
# ✓ sub-04 ses-S2: 1865 trials → sub-04_ses-S2_trials_event_locked.csv
#
# [12/63] sub-04 ses-S3
# sub-04 ses-S3 nback_0 thresh=5740.3µV
#   Rejected: {'amplitude': 157, 'kurtosis': 27, 'edge': 0, 'boundary': 3} (187/203)
#   zeroBACK       :   16
# sub-04 ses-S3 nback_1 thresh=5946.9µV
#   Rejected: {'amplitude': 66, 'kurtosis': 3, 'edge': 0, 'boundary': 3} (72/200)
#   oneBACK        :  128
# sub-04 ses-S3 nback_2 thresh=8238.3µV
#   Rejected: {'amplitude': 45, 'kurtosis': 38, 'edge': 0, 'boundary': 3} (86/208)
#   twoBACK        :  122
# sub-04 ses-S3 matb_easy thresh=9600.1µV
#   Rejected: {'amplitude': 47, 'kurtosis': 10, 'edge': 2} (59/199)
#   MATBeasy       :  140
# sub-04 ses-S3 matb_med thresh=6217.6µV
#   Rejected: {'amplitude': 150, 'kurtosis': 2, 'edge': 2} (154/199)
#   MATBmed        :   45
# sub-04 ses-S3 matb_diff thresh=5754.7µV
#   Rejected: {'amplitude': 101, 'kurtosis': 8, 'edge': 2} (111/199)
#   MATBdiff       :   88
# sub-04 ses-S3 pvt thresh=7152.2µV
#   Rejected: {'amplitude': 52, 'kurtosis': 12, 'edge': 0, 'boundary': 4} (68/273)
#   PVT            :  205
# sub-04 ses-S3 flanker thresh=5622.0µV
#   Rejected: {'amplitude': 189, 'kurtosis': 73, 'edge': 1, 'boundary': 5} (268/481)
#   Flanker        :  213
# sub-04 ses-S3 rest_begin_open thresh=10195.2µV
#   Rejected: {'amplitude': 0, 'kurtosis': 0, 'edge': 0, 'boundary': 2} (2/2)
#   RS_Beg_EO      :    0
# sub-04 ses-S3 rest_begin_closed thresh=9848.9µV
#   Rejected: {'amplitude': 0, 'kurtosis': 0, 'edge': 0, 'boundary': 2} (2/2)
#   RS_Beg_EC      :    0
# sub-04 ses-S3 rest_end_open thresh=5868.3µV
#   Rejected: {'amplitude': 0, 'kurtosis': 0, 'edge': 0, 'boundary': 2} (2/2)
#   RS_End_EO      :    0
# sub-04 ses-S3 rest_end_closed thresh=5812.7µV
#   Rejected: {'amplitude': 0, 'kurtosis': 0, 'edge': 0, 'boundary': 2} (2/2)
#   RS_End_EC      :    0
# ✓ sub-04 ses-S3: 957 trials → sub-04_ses-S3_trials_event_locked.csv
#
# [13/63] sub-05 ses-S1
# sub-05 ses-S1 nback_0 thresh=13224.6µV
#   Rejected: {'amplitude': 25, 'kurtosis': 6, 'edge': 0, 'boundary': 3} (34/203)
#   zeroBACK       :  169
# sub-05 ses-S1 nback_1 thresh=7580.4µV
#   Rejected: {'amplitude': 38, 'kurtosis': 16, 'edge': 1, 'boundary': 2} (57/200)
#   oneBACK        :  143
# sub-05 ses-S1 nback_2 thresh=12486.7µV
#   Rejected: {'amplitude': 21, 'kurtosis': 29, 'edge': 0, 'boundary': 2} (52/194)
#   twoBACK        :  142
# sub-05 ses-S1 matb_easy thresh=11369.4µV
#   Rejected: {'amplitude': 40, 'kurtosis': 10, 'edge': 2} (52/199)
#   MATBeasy       :  147
# sub-05 ses-S1 matb_med thresh=10491.4µV
#   Rejected: {'amplitude': 56, 'kurtosis': 13, 'edge': 2} (71/199)
#   MATBmed        :  128
# sub-05 ses-S1 matb_diff thresh=11100.3µV
#   Rejected: {'amplitude': 105, 'kurtosis': 30, 'edge': 2} (137/199)
#   MATBdiff       :   62
# sub-05 ses-S1 pvt thresh=8077.1µV
#   Rejected: {'amplitude': 43, 'kurtosis': 40, 'edge': 0, 'boundary': 4} (87/272)
#   PVT            :  185
# sub-05 ses-S1 flanker thresh=11774.6µV
#   Rejected: {'amplitude': 87, 'kurtosis': 109, 'edge': 0, 'boundary': 5} (201/482)
#   Flanker        :  281
# sub-05 ses-S1 rest_begin_open thresh=12560.7µV
#   Rejected: {'amplitude': 0, 'kurtosis': 0, 'edge': 0, 'boundary': 2} (2/2)
#   RS_Beg_EO      :    0
# sub-05 ses-S1 rest_begin_closed thresh=11830.6µV
#   Rejected: {'amplitude': 0, 'kurtosis': 0, 'edge': 0, 'boundary': 2} (2/2)
#   RS_Beg_EC      :    0
# sub-05 ses-S1 rest_end_open thresh=10756.3µV
#   Rejected: {'amplitude': 0, 'kurtosis': 0, 'edge': 0, 'boundary': 2} (2/2)
#   RS_End_EO      :    0
# sub-05 ses-S1 rest_end_closed thresh=10329.2µV
#   Rejected: {'amplitude': 0, 'kurtosis': 0, 'edge': 0, 'boundary': 2} (2/2)
#   RS_End_EC      :    0
# ✓ sub-05 ses-S1: 1257 trials → sub-05_ses-S1_trials_event_locked.csv
#
# [14/63] sub-05 ses-S2
# sub-05 ses-S2 nback_0 thresh=7865.9µV
#   Rejected: {'amplitude': 0, 'kurtosis': 18, 'edge': 0, 'boundary': 3} (21/203)
#   zeroBACK       :  182
# sub-05 ses-S2 nback_1 thresh=7862.5µV
#   Rejected: {'amplitude': 0, 'kurtosis': 31, 'edge': 0, 'boundary': 3} (34/200)
#   oneBACK        :  166
# sub-05 ses-S2 nback_2 thresh=8048.5µV
#   Rejected: {'amplitude': 0, 'kurtosis': 36, 'edge': 0, 'boundary': 2} (38/187)
#   twoBACK        :  149
# sub-05 ses-S2 matb_easy thresh=9065.3µV
#   Rejected: {'amplitude': 90, 'kurtosis': 46, 'edge': 2} (138/199)
#   MATBeasy       :   61
# sub-05 ses-S2 matb_med thresh=8208.9µV
#   Rejected: {'amplitude': 70, 'kurtosis': 35, 'edge': 2} (107/199)
#   MATBmed        :   92
# sub-05 ses-S2 matb_diff thresh=8782.7µV
#   Rejected: {'amplitude': 121, 'kurtosis': 26, 'edge': 2} (149/199)
#   MATBdiff       :   50
# sub-05 ses-S2 pvt thresh=9575.2µV
#   Rejected: {'amplitude': 156, 'kurtosis': 0, 'edge': 0, 'boundary': 4} (160/272)
#   PVT            :  112
# sub-05 ses-S2 flanker thresh=9671.6µV
#   Rejected: {'amplitude': 315, 'kurtosis': 15, 'edge': 1, 'boundary': 5} (336/482)
#   Flanker        :  146
# sub-05 ses-S2 rest_begin_open thresh=9631.9µV
#   Rejected: {'amplitude': 0, 'kurtosis': 0, 'edge': 0, 'boundary': 2} (2/2)
#   RS_Beg_EO      :    0
# sub-05 ses-S2 rest_begin_closed thresh=9414.8µV
#   Rejected: {'amplitude': 0, 'kurtosis': 0, 'edge': 0, 'boundary': 2} (2/2)
#   RS_Beg_EC      :    0
# sub-05 ses-S2 rest_end_open thresh=7997.0µV
#   Rejected: {'amplitude': 0, 'kurtosis': 0, 'edge': 0, 'boundary': 2} (2/2)
#   RS_End_EO      :    0
# sub-05 ses-S2 rest_end_closed thresh=8090.3µV
#   Rejected: {'amplitude': 0, 'kurtosis': 0, 'edge': 0, 'boundary': 2} (2/2)
#   RS_End_EC      :    0
# ✓ sub-05 ses-S2: 958 trials → sub-05_ses-S2_trials_event_locked.csv
#
# [15/63] sub-05 ses-S3
# sub-05 ses-S3 nback_0 thresh=8932.0µV
#   Rejected: {'amplitude': 25, 'kurtosis': 36, 'edge': 0, 'boundary': 3} (64/203)
#   zeroBACK       :  139
# sub-05 ses-S3 nback_1 thresh=7072.6µV
#   Rejected: {'amplitude': 0, 'kurtosis': 64, 'edge': 0, 'boundary': 3} (67/200)
#   oneBACK        :  133
# sub-05 ses-S3 nback_2 thresh=7484.4µV
#   Rejected: {'amplitude': 24, 'kurtosis': 61, 'edge': 0, 'boundary': 3} (88/198)
#   twoBACK        :  110
# sub-05 ses-S3 matb_easy thresh=11068.2µV
#   Rejected: {'amplitude': 70, 'kurtosis': 75, 'edge': 2} (147/199)
#   MATBeasy       :   52
# sub-05 ses-S3 matb_med thresh=7333.0µV
#   Rejected: {'amplitude': 0, 'kurtosis': 67, 'edge': 2} (69/199)
#   MATBmed        :  130
# sub-05 ses-S3 matb_diff thresh=9991.1µV
#   Rejected: {'amplitude': 0, 'kurtosis': 82, 'edge': 2} (84/199)
#   MATBdiff       :  115
# sub-05 ses-S3 pvt thresh=10746.9µV
#   Rejected: {'amplitude': 49, 'kurtosis': 42, 'edge': 0, 'boundary': 4} (95/272)
#   PVT            :  177
# sub-05 ses-S3 flanker thresh=9505.9µV
#   Rejected: {'amplitude': 76, 'kurtosis': 148, 'edge': 0, 'boundary': 6} (230/483)
#   Flanker        :  253
# sub-05 ses-S3 rest_begin_open thresh=10193.6µV
#   Rejected: {'amplitude': 0, 'kurtosis': 0, 'edge': 0, 'boundary': 2} (2/2)
#   RS_Beg_EO      :    0
# sub-05 ses-S3 rest_begin_closed thresh=10269.0µV
#   Rejected: {'amplitude': 0, 'kurtosis': 0, 'edge': 0, 'boundary': 2} (2/2)
#   RS_Beg_EC      :    0
# sub-05 ses-S3 rest_end_open thresh=6650.2µV
#   Rejected: {'amplitude': 0, 'kurtosis': 0, 'edge': 0, 'boundary': 2} (2/2)
#   RS_End_EO      :    0
# sub-05 ses-S3 rest_end_closed thresh=6776.6µV
#   Rejected: {'amplitude': 0, 'kurtosis': 0, 'edge': 0, 'boundary': 2} (2/2)
#   RS_End_EC      :    0
# ✓ sub-05 ses-S3: 1109 trials → sub-05_ses-S3_trials_event_locked.csv
#
# [16/63] sub-06 ses-S1
# sub-06 ses-S1 nback_0 thresh=2352.8µV
#   Rejected: {'amplitude': 15, 'kurtosis': 15, 'edge': 0, 'boundary': 2} (32/204)
#   zeroBACK       :  172
# sub-06 ses-S1 nback_1 thresh=2001.1µV
#   Rejected: {'amplitude': 0, 'kurtosis': 17, 'edge': 0, 'boundary': 2} (19/199)
#   oneBACK        :  180
# sub-06 ses-S1 nback_2 thresh=2268.5µV
#   Rejected: {'amplitude': 2, 'kurtosis': 10, 'edge': 0, 'boundary': 2} (14/194)
#   twoBACK        :  180
# sub-06 ses-S1 matb_easy thresh=1330.1µV
#   Rejected: {'amplitude': 42, 'kurtosis': 4, 'edge': 1} (47/198)
#   MATBeasy       :  151
# sub-06 ses-S1 matb_med thresh=1547.1µV
#   Rejected: {'amplitude': 99, 'kurtosis': 3, 'edge': 2} (104/199)
#   MATBmed        :   95
# sub-06 ses-S1 matb_diff thresh=4769.0µV
#   Rejected: {'amplitude': 79, 'kurtosis': 9, 'edge': 2} (90/199)
#   MATBdiff       :  109
# sub-06 ses-S1 pvt thresh=4220.4µV
#   Rejected: {'amplitude': 116, 'kurtosis': 6, 'edge': 0, 'boundary': 4} (126/272)
#   PVT            :  146
# sub-06 ses-S1 flanker thresh=4399.3µV
#   Rejected: {'amplitude': 0, 'kurtosis': 49, 'edge': 0, 'boundary': 5} (54/482)
#   Flanker        :  428
# sub-06 ses-S1 rest_begin_open thresh=4743.6µV
#   Rejected: {'amplitude': 0, 'kurtosis': 0, 'edge': 0, 'boundary': 2} (2/2)
#   RS_Beg_EO      :    0
# sub-06 ses-S1 rest_begin_closed thresh=4683.7µV
#   Rejected: {'amplitude': 0, 'kurtosis': 0, 'edge': 0, 'boundary': 2} (2/2)
#   RS_Beg_EC      :    0
# sub-06 ses-S1 rest_end_open thresh=1302.9µV
#   Rejected: {'amplitude': 0, 'kurtosis': 0, 'edge': 0, 'boundary': 2} (2/2)
#   RS_End_EO      :    0
# sub-06 ses-S1 rest_end_closed thresh=1031.4µV
#   Rejected: {'amplitude': 0, 'kurtosis': 0, 'edge': 0, 'boundary': 2} (2/2)
#   RS_End_EC      :    0
# ✓ sub-06 ses-S1: 1461 trials → sub-06_ses-S1_trials_event_locked.csv
#
# [17/63] sub-06 ses-S2
# sub-06 ses-S2 nback_0 thresh=13667.4µV
#   Rejected: {'amplitude': 0, 'kurtosis': 29, 'edge': 0, 'boundary': 2} (31/205)
#   zeroBACK       :  174
# sub-06 ses-S2 nback_1 thresh=11705.2µV
#   Rejected: {'amplitude': 0, 'kurtosis': 28, 'edge': 0, 'boundary': 2} (30/201)
#   oneBACK        :  171
# sub-06 ses-S2 nback_2 thresh=13265.6µV
#   Rejected: {'amplitude': 0, 'kurtosis': 34, 'edge': 0, 'boundary': 2} (36/199)
#   twoBACK        :  163
# sub-06 ses-S2 matb_easy thresh=11777.8µV
#   Rejected: {'amplitude': 0, 'kurtosis': 4, 'edge': 2} (6/199)
#   MATBeasy       :  193
# sub-06 ses-S2 matb_med thresh=12270.4µV
#   Rejected: {'amplitude': 0, 'kurtosis': 4, 'edge': 2} (6/199)
#   MATBmed        :  193
# sub-06 ses-S2 matb_diff thresh=14063.2µV
#   Rejected: {'amplitude': 0, 'kurtosis': 4, 'edge': 2} (6/199)
#   MATBdiff       :  193
# sub-06 ses-S2 pvt thresh=12239.2µV
#   Rejected: {'amplitude': 0, 'kurtosis': 40, 'edge': 0, 'boundary': 4} (44/273)
#   PVT            :  229
# sub-06 ses-S2 flanker thresh=11747.6µV
#   Rejected: {'amplitude': 0, 'kurtosis': 7, 'edge': 1, 'boundary': 5} (13/478)
#   Flanker        :  465
# sub-06 ses-S2 rest_begin_open thresh=14253.9µV
#   Rejected: {'amplitude': 0, 'kurtosis': 0, 'edge': 0, 'boundary': 2} (2/2)
#   RS_Beg_EO      :    0
# sub-06 ses-S2 rest_begin_closed thresh=14135.1µV
#   Rejected: {'amplitude': 0, 'kurtosis': 0, 'edge': 0, 'boundary': 2} (2/2)
#   RS_Beg_EC      :    0
# sub-06 ses-S2 rest_end_open thresh=11335.4µV
#   Rejected: {'amplitude': 0, 'kurtosis': 0, 'edge': 0, 'boundary': 2} (2/2)
#   RS_End_EO      :    0
# sub-06 ses-S2 rest_end_closed thresh=11559.4µV
#   Rejected: {'amplitude': 0, 'kurtosis': 0, 'edge': 0, 'boundary': 2} (2/2)
#   RS_End_EC      :    0
# ✓ sub-06 ses-S2: 1781 trials → sub-06_ses-S2_trials_event_locked.csv
#
# [18/63] sub-06 ses-S3
# sub-06 ses-S3 nback_0 thresh=8811.5µV
#   Rejected: {'amplitude': 48, 'kurtosis': 0, 'edge': 0, 'boundary': 3} (51/204)
#   zeroBACK       :  153
# sub-06 ses-S3 nback_1 thresh=7467.1µV
#   Rejected: {'amplitude': 60, 'kurtosis': 13, 'edge': 1, 'boundary': 2} (76/196)
#   oneBACK        :  120
# sub-06 ses-S3 nback_2 thresh=8152.4µV
#   Rejected: {'amplitude': 39, 'kurtosis': 5, 'edge': 2, 'boundary': 3} (49/201)
#   twoBACK        :  152
# sub-06 ses-S3 matb_easy thresh=7716.1µV
#   Rejected: {'amplitude': 94, 'kurtosis': 0, 'edge': 2} (96/199)
#   MATBeasy       :  103
# sub-06 ses-S3 matb_med thresh=7657.5µV
#   Rejected: {'amplitude': 142, 'kurtosis': 0, 'edge': 2} (144/199)
#   MATBmed        :   55
# sub-06 ses-S3 matb_diff thresh=7658.6µV
#   Rejected: {'amplitude': 102, 'kurtosis': 0, 'edge': 2} (104/199)
#   MATBdiff       :   95
# sub-06 ses-S3 pvt thresh=7692.5µV
#   Rejected: {'amplitude': 145, 'kurtosis': 7, 'edge': 0, 'boundary': 4} (156/272)
#   PVT            :  116
# sub-06 ses-S3 flanker thresh=7546.1µV
#   Rejected: {'amplitude': 98, 'kurtosis': 24, 'edge': 1, 'boundary': 5} (128/480)
#   Flanker        :  352
# sub-06 ses-S3 rest_begin_open thresh=8966.9µV
#   Rejected: {'amplitude': 0, 'kurtosis': 0, 'edge': 0, 'boundary': 2} (2/2)
#   RS_Beg_EO      :    0
# sub-06 ses-S3 rest_begin_closed thresh=9000.4µV
#   Rejected: {'amplitude': 0, 'kurtosis': 0, 'edge': 0, 'boundary': 2} (2/2)
#   RS_Beg_EC      :    0
# sub-06 ses-S3 rest_end_open thresh=7733.7µV
#   Rejected: {'amplitude': 0, 'kurtosis': 0, 'edge': 0, 'boundary': 2} (2/2)
#   RS_End_EO      :    0
# sub-06 ses-S3 rest_end_closed thresh=7697.1µV
#   Rejected: {'amplitude': 0, 'kurtosis': 0, 'edge': 0, 'boundary': 2} (2/2)
#   RS_End_EC      :    0
# ✓ sub-06 ses-S3: 1146 trials → sub-06_ses-S3_trials_event_locked.csv
#
# [19/63] sub-07 ses-S1
# sub-07 ses-S1 nback_0 thresh=11787.3µV
#   Rejected: {'amplitude': 125, 'kurtosis': 20, 'edge': 0, 'boundary': 2} (147/203)
#   zeroBACK       :   56
# sub-07 ses-S1 nback_1 thresh=11810.3µV
#   Rejected: {'amplitude': 145, 'kurtosis': 9, 'edge': 0, 'boundary': 3} (157/201)
#   oneBACK        :   44
# sub-07 ses-S1 nback_2 thresh=11830.1µV
#   Rejected: {'amplitude': 134, 'kurtosis': 13, 'edge': 0, 'boundary': 2} (149/210)
#   twoBACK        :   61
# sub-07 ses-S1 matb_easy thresh=11765.7µV
#   Rejected: {'amplitude': 177, 'kurtosis': 0, 'edge': 2} (179/199)
#   MATBeasy       :   20
# sub-07 ses-S1 matb_med thresh=11851.4µV
#   Rejected: {'amplitude': 162, 'kurtosis': 8, 'edge': 2} (172/199)
#   MATBmed        :   27
# sub-07 ses-S1 matb_diff thresh=11980.2µV
#   Rejected: {'amplitude': 156, 'kurtosis': 2, 'edge': 2} (160/199)
#   MATBdiff       :   39
# sub-07 ses-S1 pvt thresh=11899.2µV
#   Rejected: {'amplitude': 164, 'kurtosis': 33, 'edge': 0, 'boundary': 4} (201/273)
#   PVT            :   72
# sub-07 ses-S1 flanker thresh=11963.4µV
#   Rejected: {'amplitude': 168, 'kurtosis': 152, 'edge': 1, 'boundary': 5} (326/483)
#   Flanker        :  157
# sub-07 ses-S1 rest_begin_open thresh=12421.2µV
#   Rejected: {'amplitude': 0, 'kurtosis': 0, 'edge': 0, 'boundary': 2} (2/2)
#   RS_Beg_EO      :    0
# sub-07 ses-S1 rest_begin_closed thresh=12145.6µV
#   Rejected: {'amplitude': 0, 'kurtosis': 0, 'edge': 0, 'boundary': 2} (2/2)
#   RS_Beg_EC      :    0
# sub-07 ses-S1 rest_end_open thresh=11708.9µV
#   Rejected: {'amplitude': 0, 'kurtosis': 0, 'edge': 0, 'boundary': 2} (2/2)
#   RS_End_EO      :    0
# sub-07 ses-S1 rest_end_closed thresh=11575.0µV
#   Rejected: {'amplitude': 0, 'kurtosis': 0, 'edge': 0, 'boundary': 2} (2/2)
#   RS_End_EC      :    0
# ✓ sub-07 ses-S1: 476 trials → sub-07_ses-S1_trials_event_locked.csv
#
# [20/63] sub-07 ses-S2
# sub-07 ses-S2 nback_0 thresh=9098.9µV
#   Rejected: {'amplitude': 0, 'kurtosis': 21, 'edge': 0, 'boundary': 3} (24/204)
#   zeroBACK       :  180
# sub-07 ses-S2 nback_1 thresh=9992.9µV
#   Rejected: {'amplitude': 0, 'kurtosis': 38, 'edge': 0, 'boundary': 3} (41/201)
#   oneBACK        :  160
# sub-07 ses-S2 nback_2 thresh=10461.3µV
#   Rejected: {'amplitude': 0, 'kurtosis': 39, 'edge': 0, 'boundary': 3} (42/204)
#   twoBACK        :  162
# sub-07 ses-S2 matb_easy thresh=9826.3µV
#   Rejected: {'amplitude': 0, 'kurtosis': 19, 'edge': 2} (21/199)
#   MATBeasy       :  178
# sub-07 ses-S2 matb_med thresh=10531.1µV
#   Rejected: {'amplitude': 0, 'kurtosis': 8, 'edge': 2} (10/199)
#   MATBmed        :  189
# sub-07 ses-S2 matb_diff thresh=9764.0µV
#   Rejected: {'amplitude': 0, 'kurtosis': 16, 'edge': 2} (18/199)
#   MATBdiff       :  181
# sub-07 ses-S2 pvt thresh=10889.9µV
#   Rejected: {'amplitude': 0, 'kurtosis': 80, 'edge': 0, 'boundary': 4} (84/272)
#   PVT            :  188
# sub-07 ses-S2 flanker thresh=9466.4µV
#   Rejected: {'amplitude': 0, 'kurtosis': 129, 'edge': 1, 'boundary': 5} (135/483)
#   Flanker        :  348
# sub-07 ses-S2 rest_begin_open thresh=10589.4µV
#   Rejected: {'amplitude': 0, 'kurtosis': 0, 'edge': 0, 'boundary': 2} (2/2)
#   RS_Beg_EO      :    0
# sub-07 ses-S2 rest_begin_closed thresh=10601.5µV
#   Rejected: {'amplitude': 0, 'kurtosis': 0, 'edge': 0, 'boundary': 2} (2/2)
#   RS_Beg_EC      :    0
# sub-07 ses-S2 rest_end_open thresh=8940.4µV
#   Rejected: {'amplitude': 0, 'kurtosis': 0, 'edge': 0, 'boundary': 2} (2/2)
#   RS_End_EO      :    0
# sub-07 ses-S2 rest_end_closed thresh=8852.2µV
#   Rejected: {'amplitude': 0, 'kurtosis': 0, 'edge': 0, 'boundary': 2} (2/2)
#   RS_End_EC      :    0
# ✓ sub-07 ses-S2: 1586 trials → sub-07_ses-S2_trials_event_locked.csv
#
# [21/63] sub-07 ses-S3
# sub-07 ses-S3 nback_0 thresh=8607.4µV
#   Rejected: {'amplitude': 39, 'kurtosis': 3, 'edge': 0, 'boundary': 3} (45/203)
#   zeroBACK       :  158
# sub-07 ses-S3 nback_1 thresh=7662.0µV
#   Rejected: {'amplitude': 94, 'kurtosis': 8, 'edge': 0, 'boundary': 3} (105/200)
#   oneBACK        :   95
# sub-07 ses-S3 nback_2 thresh=8272.4µV
#   Rejected: {'amplitude': 89, 'kurtosis': 22, 'edge': 0, 'boundary': 3} (114/204)
#   twoBACK        :   90
# sub-07 ses-S3 matb_easy thresh=7873.4µV
#   Rejected: {'amplitude': 50, 'kurtosis': 6, 'edge': 2} (58/199)
#   MATBeasy       :  141
# sub-07 ses-S3 matb_med thresh=8407.4µV
#   Rejected: {'amplitude': 41, 'kurtosis': 1, 'edge': 2} (44/199)
#   MATBmed        :  155
# sub-07 ses-S3 matb_diff thresh=10739.1µV
#   Rejected: {'amplitude': 104, 'kurtosis': 2, 'edge': 2} (108/199)
#   MATBdiff       :   91
# sub-07 ses-S3 pvt thresh=7254.4µV
#   Rejected: {'amplitude': 111, 'kurtosis': 27, 'edge': 0, 'boundary': 4} (142/273)
#   PVT            :  131
# sub-07 ses-S3 flanker thresh=9972.0µV
#   Rejected: {'amplitude': 152, 'kurtosis': 21, 'edge': 1, 'boundary': 5} (179/483)
#   Flanker        :  304
# sub-07 ses-S3 rest_begin_open thresh=11251.4µV
#   Rejected: {'amplitude': 0, 'kurtosis': 0, 'edge': 0, 'boundary': 2} (2/2)
#   RS_Beg_EO      :    0
# sub-07 ses-S3 rest_begin_closed thresh=11234.0µV
#   Rejected: {'amplitude': 0, 'kurtosis': 0, 'edge': 0, 'boundary': 2} (2/2)
#   RS_Beg_EC      :    0
# sub-07 ses-S3 rest_end_open thresh=7420.9µV
#   Rejected: {'amplitude': 0, 'kurtosis': 0, 'edge': 0, 'boundary': 2} (2/2)
#   RS_End_EO      :    0
# sub-07 ses-S3 rest_end_closed thresh=7363.7µV
#   Rejected: {'amplitude': 0, 'kurtosis': 0, 'edge': 0, 'boundary': 2} (2/2)
#   RS_End_EC      :    0
# ✓ sub-07 ses-S3: 1165 trials → sub-07_ses-S3_trials_event_locked.csv
#
# [22/63] sub-08 ses-S1
# sub-08 ses-S1 nback_0 thresh=6583.9µV
#   Rejected: {'amplitude': 123, 'kurtosis': 0, 'edge': 1, 'boundary': 2} (126/202)
#   zeroBACK       :   76
# sub-08 ses-S1 nback_1 thresh=7029.6µV
#   Rejected: {'amplitude': 69, 'kurtosis': 0, 'edge': 0, 'boundary': 2} (71/200)
#   oneBACK        :  129
# sub-08 ses-S1 nback_2 thresh=6589.0µV
#   Rejected: {'amplitude': 151, 'kurtosis': 0, 'edge': 2, 'boundary': 3} (156/204)
#   twoBACK        :   48
# sub-08 ses-S1 matb_easy thresh=6626.6µV
#   Rejected: {'amplitude': 155, 'kurtosis': 0, 'edge': 2} (157/199)
#   MATBeasy       :   42
# sub-08 ses-S1 matb_med thresh=6702.6µV
#   Rejected: {'amplitude': 109, 'kurtosis': 0, 'edge': 2} (111/199)
#   MATBmed        :   88
# sub-08 ses-S1 matb_diff thresh=6676.7µV
#   Rejected: {'amplitude': 73, 'kurtosis': 1, 'edge': 2} (76/199)
#   MATBdiff       :  123
# sub-08 ses-S1 pvt thresh=6740.3µV
#   Rejected: {'amplitude': 111, 'kurtosis': 0, 'edge': 0, 'boundary': 4} (115/273)
#   PVT            :  158
# sub-08 ses-S1 flanker thresh=6957.9µV
#   Rejected: {'amplitude': 310, 'kurtosis': 0, 'edge': 1, 'boundary': 5} (316/483)
#   Flanker        :  167
# sub-08 ses-S1 rest_begin_open thresh=7001.9µV
#   Rejected: {'amplitude': 0, 'kurtosis': 0, 'edge': 0, 'boundary': 2} (2/2)
#   RS_Beg_EO      :    0
# sub-08 ses-S1 rest_begin_closed thresh=6836.1µV
#   Rejected: {'amplitude': 0, 'kurtosis': 0, 'edge': 0, 'boundary': 2} (2/2)
#   RS_Beg_EC      :    0
# sub-08 ses-S1 rest_end_open thresh=7026.3µV
#   Rejected: {'amplitude': 0, 'kurtosis': 0, 'edge': 0, 'boundary': 2} (2/2)
#   RS_End_EO      :    0
# sub-08 ses-S1 rest_end_closed thresh=6928.4µV
#   Rejected: {'amplitude': 0, 'kurtosis': 0, 'edge': 0, 'boundary': 2} (2/2)
#   RS_End_EC      :    0
# ✓ sub-08 ses-S1: 831 trials → sub-08_ses-S1_trials_event_locked.csv
#
# [23/63] sub-08 ses-S2
# sub-08 ses-S2 nback_0 thresh=21091.8µV
#   Rejected: {'amplitude': 161, 'kurtosis': 0, 'edge': 0, 'boundary': 2} (163/204)
#   zeroBACK       :   41
# sub-08 ses-S2 nback_1 thresh=21124.1µV
#   Rejected: {'amplitude': 154, 'kurtosis': 0, 'edge': 0, 'boundary': 2} (156/201)
#   oneBACK        :   45
# sub-08 ses-S2 nback_2 thresh=20791.3µV
#   Rejected: {'amplitude': 76, 'kurtosis': 0, 'edge': 0, 'boundary': 2} (78/200)
#   twoBACK        :  122
# sub-08 ses-S2 matb_easy thresh=21145.2µV
#   Rejected: {'amplitude': 152, 'kurtosis': 0, 'edge': 2} (154/199)
#   MATBeasy       :   45
# sub-08 ses-S2 matb_med thresh=21013.4µV
#   Rejected: {'amplitude': 118, 'kurtosis': 0, 'edge': 2} (120/199)
#   MATBmed        :   79
# sub-08 ses-S2 matb_diff thresh=21107.5µV
#   Rejected: {'amplitude': 172, 'kurtosis': 0, 'edge': 2} (174/199)
#   MATBdiff       :   25
# sub-08 ses-S2 pvt thresh=21045.2µV
#   Rejected: {'amplitude': 147, 'kurtosis': 0, 'edge': 0, 'boundary': 4} (151/272)
#   PVT            :  121
# sub-08 ses-S2 flanker thresh=21036.2µV
#   Rejected: {'amplitude': 280, 'kurtosis': 0, 'edge': 0, 'boundary': 5} (285/482)
#   Flanker        :  197
# sub-08 ses-S2 rest_begin_open thresh=19890.5µV
#   Rejected: {'amplitude': 0, 'kurtosis': 0, 'edge': 0, 'boundary': 2} (2/2)
#   RS_Beg_EO      :    0
# sub-08 ses-S2 rest_begin_closed thresh=19940.2µV
#   Rejected: {'amplitude': 0, 'kurtosis': 0, 'edge': 0, 'boundary': 2} (2/2)
#   RS_Beg_EC      :    0
# sub-08 ses-S2 rest_end_open thresh=21137.1µV
#   Rejected: {'amplitude': 0, 'kurtosis': 0, 'edge': 0, 'boundary': 2} (2/2)
#   RS_End_EO      :    0
# sub-08 ses-S2 rest_end_closed thresh=21028.7µV
#   Rejected: {'amplitude': 0, 'kurtosis': 0, 'edge': 0, 'boundary': 2} (2/2)
#   RS_End_EC      :    0
# ✓ sub-08 ses-S2: 675 trials → sub-08_ses-S2_trials_event_locked.csv
#
# [24/63] sub-08 ses-S3
# sub-08 ses-S3 nback_0 thresh=13980.2µV
#   Rejected: {'amplitude': 192, 'kurtosis': 0, 'edge': 0, 'boundary': 2} (194/205)
#   zeroBACK       :   11
# sub-08 ses-S3 nback_1 thresh=13778.9µV
#   Rejected: {'amplitude': 163, 'kurtosis': 0, 'edge': 0, 'boundary': 2} (165/203)
#   oneBACK        :   38
# sub-08 ses-S3 nback_2 thresh=13194.3µV
#   Rejected: {'amplitude': 140, 'kurtosis': 0, 'edge': 0, 'boundary': 2} (142/211)
#   twoBACK        :   69
# sub-08 ses-S3 matb_easy thresh=13424.5µV
#   Rejected: {'amplitude': 129, 'kurtosis': 0, 'edge': 2} (131/199)
#   MATBeasy       :   68
# sub-08 ses-S3 matb_med thresh=12934.3µV
#   Rejected: {'amplitude': 153, 'kurtosis': 0, 'edge': 2} (155/199)
#   MATBmed        :   44
# sub-08 ses-S3 matb_diff thresh=13288.9µV
#   Rejected: {'amplitude': 176, 'kurtosis': 0, 'edge': 2} (178/199)
#   MATBdiff       :   21
# sub-08 ses-S3 pvt thresh=13534.4µV
#   Rejected: {'amplitude': 175, 'kurtosis': 0, 'edge': 0, 'boundary': 4} (179/272)
#   PVT            :   93
# sub-08 ses-S3 flanker thresh=13871.4µV
#   Rejected: {'amplitude': 423, 'kurtosis': 0, 'edge': 0, 'boundary': 5} (428/483)
#   Flanker        :   55
# sub-08 ses-S3 rest_begin_open thresh=12964.2µV
#   Rejected: {'amplitude': 0, 'kurtosis': 0, 'edge': 0, 'boundary': 2} (2/2)
#   RS_Beg_EO      :    0
# sub-08 ses-S3 rest_begin_closed thresh=13217.7µV
#   Rejected: {'amplitude': 0, 'kurtosis': 0, 'edge': 0, 'boundary': 2} (2/2)
#   RS_Beg_EC      :    0
# sub-08 ses-S3 rest_end_open thresh=13647.2µV
#   Rejected: {'amplitude': 0, 'kurtosis': 0, 'edge': 0, 'boundary': 2} (2/2)
#   RS_End_EO      :    0
# sub-08 ses-S3 rest_end_closed thresh=13508.8µV
#   Rejected: {'amplitude': 0, 'kurtosis': 0, 'edge': 0, 'boundary': 2} (2/2)
#   RS_End_EC      :    0
# ✓ sub-08 ses-S3: 399 trials → sub-08_ses-S3_trials_event_locked.csv
#
# [25/63] sub-09 ses-S1
# sub-09 ses-S1 nback_0 thresh=7305.8µV
#   Rejected: {'amplitude': 0, 'kurtosis': 35, 'edge': 0, 'boundary': 3} (38/203)
#   zeroBACK       :  165
# sub-09 ses-S1 nback_1 thresh=5033.4µV
#   Rejected: {'amplitude': 0, 'kurtosis': 54, 'edge': 0, 'boundary': 2} (56/199)
#   oneBACK        :  143
# sub-09 ses-S1 nback_2 thresh=6987.6µV
#   Rejected: {'amplitude': 0, 'kurtosis': 79, 'edge': 0, 'boundary': 2} (81/206)
#   twoBACK        :  125
# sub-09 ses-S1 matb_easy thresh=3995.5µV
#   Rejected: {'amplitude': 0, 'kurtosis': 14, 'edge': 2} (16/199)
#   MATBeasy       :  183
# sub-09 ses-S1 matb_med thresh=5880.4µV
#   Rejected: {'amplitude': 0, 'kurtosis': 33, 'edge': 2} (35/199)
#   MATBmed        :  164
# sub-09 ses-S1 matb_diff thresh=4326.6µV
#   Rejected: {'amplitude': 0, 'kurtosis': 18, 'edge': 2} (20/199)
#   MATBdiff       :  179
# sub-09 ses-S1 pvt thresh=7462.7µV
#   Rejected: {'amplitude': 0, 'kurtosis': 125, 'edge': 0, 'boundary': 4} (129/272)
#   PVT            :  143
# sub-09 ses-S1 flanker thresh=7863.7µV
#   Rejected: {'amplitude': 0, 'kurtosis': 57, 'edge': 0, 'boundary': 5} (62/483)
#   Flanker        :  421
# sub-09 ses-S1 rest_begin_open thresh=2573.5µV
#   Rejected: {'amplitude': 0, 'kurtosis': 0, 'edge': 0, 'boundary': 2} (2/2)
#   RS_Beg_EO      :    0
# sub-09 ses-S1 rest_begin_closed thresh=2985.2µV
#   Rejected: {'amplitude': 0, 'kurtosis': 0, 'edge': 0, 'boundary': 2} (2/2)
#   RS_Beg_EC      :    0
# sub-09 ses-S1 rest_end_open thresh=7225.5µV
#   Rejected: {'amplitude': 0, 'kurtosis': 0, 'edge': 0, 'boundary': 2} (2/2)
#   RS_End_EO      :    0
# sub-09 ses-S1 rest_end_closed thresh=7549.8µV
#   Rejected: {'amplitude': 0, 'kurtosis': 0, 'edge': 0, 'boundary': 2} (2/2)
#   RS_End_EC      :    0
# ✓ sub-09 ses-S1: 1523 trials → sub-09_ses-S1_trials_event_locked.csv
#
# [26/63] sub-09 ses-S2
# sub-09 ses-S2 nback_0 thresh=5797.5µV
#   Rejected: {'amplitude': 0, 'kurtosis': 51, 'edge': 0, 'boundary': 3} (54/203)
#   zeroBACK       :  149
# sub-09 ses-S2 nback_1 thresh=6445.8µV
#   Rejected: {'amplitude': 0, 'kurtosis': 57, 'edge': 0, 'boundary': 2} (59/200)
#   oneBACK        :  141
# sub-09 ses-S2 nback_2 thresh=6970.5µV
#   Rejected: {'amplitude': 0, 'kurtosis': 94, 'edge': 0, 'boundary': 2} (96/211)
#   twoBACK        :  115
# sub-09 ses-S2 matb_easy thresh=6119.4µV
#   Rejected: {'amplitude': 0, 'kurtosis': 22, 'edge': 2} (24/199)
#   MATBeasy       :  175
# sub-09 ses-S2 matb_med thresh=4777.4µV
#   Rejected: {'amplitude': 0, 'kurtosis': 50, 'edge': 2} (52/199)
#   MATBmed        :  147
# sub-09 ses-S2 matb_diff thresh=6130.2µV
#   Rejected: {'amplitude': 0, 'kurtosis': 63, 'edge': 2} (65/199)
#   MATBdiff       :  134
# sub-09 ses-S2 pvt thresh=4730.1µV
#   Rejected: {'amplitude': 0, 'kurtosis': 95, 'edge': 0, 'boundary': 4} (99/272)
#   PVT            :  173
# sub-09 ses-S2 flanker thresh=6281.6µV
#   Rejected: {'amplitude': 0, 'kurtosis': 88, 'edge': 1, 'boundary': 5} (94/483)
#   Flanker        :  389
# sub-09 ses-S2 rest_begin_open thresh=4890.2µV
#   Rejected: {'amplitude': 0, 'kurtosis': 0, 'edge': 0, 'boundary': 2} (2/2)
#   RS_Beg_EO      :    0
# sub-09 ses-S2 rest_begin_closed thresh=5332.8µV
#   Rejected: {'amplitude': 0, 'kurtosis': 0, 'edge': 0, 'boundary': 2} (2/2)
#   RS_Beg_EC      :    0
# sub-09 ses-S2 rest_end_open thresh=6713.1µV
#   Rejected: {'amplitude': 0, 'kurtosis': 0, 'edge': 0, 'boundary': 2} (2/2)
#   RS_End_EO      :    0
# sub-09 ses-S2 rest_end_closed thresh=7240.6µV
#   Rejected: {'amplitude': 0, 'kurtosis': 0, 'edge': 0, 'boundary': 2} (2/2)
#   RS_End_EC      :    0
# ✓ sub-09 ses-S2: 1423 trials → sub-09_ses-S2_trials_event_locked.csv
#
# [27/63] sub-09 ses-S3
# sub-09 ses-S3 nback_0 thresh=6938.9µV
#   Rejected: {'amplitude': 142, 'kurtosis': 0, 'edge': 0, 'boundary': 3} (145/204)
#   zeroBACK       :   59
# sub-09 ses-S3 nback_1 thresh=7581.7µV
#   Rejected: {'amplitude': 120, 'kurtosis': 0, 'edge': 0, 'boundary': 3} (123/200)
#   oneBACK        :   77
# sub-09 ses-S3 nback_2 thresh=10241.7µV
#   Rejected: {'amplitude': 111, 'kurtosis': 0, 'edge': 0, 'boundary': 3} (114/210)
#   twoBACK        :   96
# sub-09 ses-S3 matb_easy thresh=7525.0µV
#   Rejected: {'amplitude': 90, 'kurtosis': 0, 'edge': 2} (92/199)
#   MATBeasy       :  107
# sub-09 ses-S3 matb_med thresh=7482.8µV
#   Rejected: {'amplitude': 180, 'kurtosis': 0, 'edge': 2} (182/199)
#   MATBmed        :   17
# sub-09 ses-S3 matb_diff thresh=7714.5µV
#   Rejected: {'amplitude': 194, 'kurtosis': 0, 'edge': 2} (196/199)
#   MATBdiff       :    3
# sub-09 ses-S3 pvt thresh=9127.8µV
#   Rejected: {'amplitude': 104, 'kurtosis': 0, 'edge': 0, 'boundary': 4} (108/273)
#   PVT            :  165
# sub-09 ses-S3 flanker thresh=9879.8µV
#   Rejected: {'amplitude': 185, 'kurtosis': 0, 'edge': 1, 'boundary': 5} (191/481)
#   Flanker        :  290
# sub-09 ses-S3 rest_begin_open thresh=10139.5µV
#   Rejected: {'amplitude': 0, 'kurtosis': 0, 'edge': 0, 'boundary': 2} (2/2)
#   RS_Beg_EO      :    0
# sub-09 ses-S3 rest_begin_closed thresh=10219.9µV
#   Rejected: {'amplitude': 0, 'kurtosis': 0, 'edge': 0, 'boundary': 2} (2/2)
#   RS_Beg_EC      :    0
# sub-09 ses-S3 rest_end_open thresh=6579.7µV
#   Rejected: {'amplitude': 0, 'kurtosis': 0, 'edge': 0, 'boundary': 2} (2/2)
#   RS_End_EO      :    0
# sub-09 ses-S3 rest_end_closed thresh=6765.2µV
#   Rejected: {'amplitude': 0, 'kurtosis': 0, 'edge': 0, 'boundary': 2} (2/2)
# ...
#   oneBACK        :  198
# sub-19 ses-S1 nback_2 thresh=13078.1µV
#   Rejected: {'amplitude': 0, 'kurtosis': 0, 'edge': 0, 'boundary': 3} (3/200)
#   twoBACK        :  197
# sub-19 ses-S1 matb_easy thresh=14509.8µV
#   Rejected: {'amplitude': 0, 'kurtosis': 0, 'edge': 2} (2/199)
#   MATBeasy       :  197
# sub-19 ses-S1 matb_med thresh=16058.4µV
#   Rejected: {'amplitude': 0, 'kurtosis': 0, 'edge': 2} (2/199)
#   MATBmed        :  197
# sub-19 ses-S1 matb_diff thresh=14909.5µV
#   Rejected: {'amplitude': 0, 'kurtosis': 0, 'edge': 2} (2/199)
#   MATBdiff       :  197
# sub-19 ses-S1 pvt thresh=18290.9µV
#   Rejected: {'amplitude': 0, 'kurtosis': 0, 'edge': 0, 'boundary': 4} (4/273)
#   PVT            :  269
# sub-19 ses-S1 flanker thresh=13207.9µV
#   Rejected: {'amplitude': 0, 'kurtosis': 0, 'edge': 0, 'boundary': 5} (5/483)
#   Flanker        :  478
# sub-19 ses-S1 rest_begin_open thresh=18771.8µV
#   Rejected: {'amplitude': 0, 'kurtosis': 0, 'edge': 0, 'boundary': 2} (2/2)
#   RS_Beg_EO      :    0
# sub-19 ses-S1 rest_begin_closed thresh=19301.4µV
#   Rejected: {'amplitude': 0, 'kurtosis': 0, 'edge': 0, 'boundary': 2} (2/2)
#   RS_Beg_EC      :    0
# sub-19 ses-S1 rest_end_open thresh=12452.4µV
#   Rejected: {'amplitude': 0, 'kurtosis': 0, 'edge': 0, 'boundary': 2} (2/2)
#   RS_End_EO      :    0
# sub-19 ses-S1 rest_end_closed thresh=12800.7µV
#   Rejected: {'amplitude': 0, 'kurtosis': 0, 'edge': 0, 'boundary': 2} (2/2)
#   RS_End_EC      :    0
# ✓ sub-19 ses-S1: 1933 trials → sub-19_ses-S1_trials_event_locked.csv
#
# [56/63] sub-19 ses-S2
# sub-19 ses-S2 nback_0 thresh=9711.6µV
#   Rejected: {'amplitude': 0, 'kurtosis': 10, 'edge': 0, 'boundary': 3} (13/203)
#   zeroBACK       :  190
# sub-19 ses-S2 nback_1 thresh=9442.0µV
#   Rejected: {'amplitude': 0, 'kurtosis': 3, 'edge': 0, 'boundary': 3} (6/201)
#   oneBACK        :  195
# sub-19 ses-S2 nback_2 thresh=9871.7µV
#   Rejected: {'amplitude': 0, 'kurtosis': 14, 'edge': 1, 'boundary': 3} (18/206)
#   twoBACK        :  188
# sub-19 ses-S2 matb_easy thresh=9139.4µV
#   Rejected: {'amplitude': 0, 'kurtosis': 17, 'edge': 2} (19/199)
#   MATBeasy       :  180
# sub-19 ses-S2 matb_med thresh=10052.5µV
#   Rejected: {'amplitude': 0, 'kurtosis': 4, 'edge': 2} (6/199)
#   MATBmed        :  193
# sub-19 ses-S2 matb_diff thresh=10245.3µV
#   Rejected: {'amplitude': 0, 'kurtosis': 1, 'edge': 2} (3/199)
#   MATBdiff       :  196
# sub-19 ses-S2 pvt thresh=9273.7µV
#   Rejected: {'amplitude': 0, 'kurtosis': 0, 'edge': 0, 'boundary': 4} (4/273)
#   PVT            :  269
# sub-19 ses-S2 flanker thresh=10001.8µV
#   Rejected: {'amplitude': 0, 'kurtosis': 6, 'edge': 0, 'boundary': 5} (11/484)
#   Flanker        :  473
# sub-19 ses-S2 rest_begin_open thresh=9293.2µV
#   Rejected: {'amplitude': 0, 'kurtosis': 0, 'edge': 0, 'boundary': 2} (2/2)
#   RS_Beg_EO      :    0
# sub-19 ses-S2 rest_begin_closed thresh=9924.9µV
#   Rejected: {'amplitude': 0, 'kurtosis': 0, 'edge': 0, 'boundary': 2} (2/2)
#   RS_Beg_EC      :    0
# sub-19 ses-S2 rest_end_open thresh=8993.4µV
#   Rejected: {'amplitude': 0, 'kurtosis': 0, 'edge': 0, 'boundary': 2} (2/2)
#   RS_End_EO      :    0
# sub-19 ses-S2 rest_end_closed thresh=9291.2µV
#   Rejected: {'amplitude': 0, 'kurtosis': 0, 'edge': 0, 'boundary': 2} (2/2)
#   RS_End_EC      :    0
# ✓ sub-19 ses-S2: 1884 trials → sub-19_ses-S2_trials_event_locked.csv
#
# [57/63] sub-19 ses-S3
# sub-19 ses-S3 nback_0 thresh=11151.7µV
#   Rejected: {'amplitude': 34, 'kurtosis': 63, 'edge': 0, 'boundary': 3} (100/203)
#   zeroBACK       :  103
# sub-19 ses-S3 nback_1 thresh=12192.5µV
#   Rejected: {'amplitude': 78, 'kurtosis': 57, 'edge': 0, 'boundary': 3} (138/199)
#   oneBACK        :   61
# sub-19 ses-S3 nback_2 thresh=11567.6µV
#   Rejected: {'amplitude': 49, 'kurtosis': 68, 'edge': 0, 'boundary': 3} (120/206)
#   twoBACK        :   86
# sub-19 ses-S3 matb_easy thresh=9981.1µV
#   Rejected: {'amplitude': 49, 'kurtosis': 14, 'edge': 2} (65/199)
#   MATBeasy       :  134
# sub-19 ses-S3 matb_med thresh=13499.2µV
#   Rejected: {'amplitude': 37, 'kurtosis': 9, 'edge': 2} (48/199)
#   MATBmed        :  151
# sub-19 ses-S3 matb_diff thresh=13166.6µV
#   Rejected: {'amplitude': 47, 'kurtosis': 3, 'edge': 2} (52/199)
#   MATBdiff       :  147
# sub-19 ses-S3 pvt thresh=8986.0µV
#   Rejected: {'amplitude': 58, 'kurtosis': 60, 'edge': 0, 'boundary': 4} (122/273)
#   PVT            :  151
# sub-19 ses-S3 flanker thresh=13405.3µV
#   Rejected: {'amplitude': 94, 'kurtosis': 165, 'edge': 0, 'boundary': 5} (264/482)
#   Flanker        :  218
# sub-19 ses-S3 rest_begin_open thresh=6759.7µV
#   Rejected: {'amplitude': 0, 'kurtosis': 0, 'edge': 0, 'boundary': 2} (2/2)
#   RS_Beg_EO      :    0
# sub-19 ses-S3 rest_begin_closed thresh=6462.1µV
#   Rejected: {'amplitude': 0, 'kurtosis': 0, 'edge': 0, 'boundary': 2} (2/2)
#   RS_Beg_EC      :    0
# sub-19 ses-S3 rest_end_open thresh=13329.1µV
#   Rejected: {'amplitude': 0, 'kurtosis': 0, 'edge': 0, 'boundary': 2} (2/2)
#   RS_End_EO      :    0
# sub-19 ses-S3 rest_end_closed thresh=13030.8µV
#   Rejected: {'amplitude': 0, 'kurtosis': 0, 'edge': 0, 'boundary': 2} (2/2)
#   RS_End_EC      :    0
# ✓ sub-19 ses-S3: 1051 trials → sub-19_ses-S3_trials_event_locked.csv
#
# [58/63] sub-20 ses-S1
# sub-20 ses-S1 nback_0 thresh=13674.9µV
#   Rejected: {'amplitude': 0, 'kurtosis': 0, 'edge': 1, 'boundary': 2} (3/203)
#   zeroBACK       :  200
# sub-20 ses-S1 nback_1 thresh=13754.3µV
#   Rejected: {'amplitude': 0, 'kurtosis': 0, 'edge': 0, 'boundary': 3} (3/201)
#   oneBACK        :  198
# sub-20 ses-S1 nback_2 thresh=13078.1µV
#   Rejected: {'amplitude': 0, 'kurtosis': 0, 'edge': 0, 'boundary': 3} (3/200)
#   twoBACK        :  197
# sub-20 ses-S1 matb_easy thresh=14509.8µV
#   Rejected: {'amplitude': 0, 'kurtosis': 0, 'edge': 2} (2/199)
#   MATBeasy       :  197
# sub-20 ses-S1 matb_med thresh=16058.4µV
#   Rejected: {'amplitude': 0, 'kurtosis': 0, 'edge': 2} (2/199)
#   MATBmed        :  197
# sub-20 ses-S1 matb_diff thresh=14909.5µV
#   Rejected: {'amplitude': 0, 'kurtosis': 0, 'edge': 2} (2/199)
#   MATBdiff       :  197
# sub-20 ses-S1 pvt thresh=18290.9µV
#   Rejected: {'amplitude': 0, 'kurtosis': 0, 'edge': 0, 'boundary': 4} (4/273)
#   PVT            :  269
# sub-20 ses-S1 flanker thresh=13207.9µV
#   Rejected: {'amplitude': 0, 'kurtosis': 0, 'edge': 0, 'boundary': 5} (5/483)
#   Flanker        :  478
# sub-20 ses-S1 rest_begin_open thresh=18771.8µV
#   Rejected: {'amplitude': 0, 'kurtosis': 0, 'edge': 0, 'boundary': 2} (2/2)
#   RS_Beg_EO      :    0
# sub-20 ses-S1 rest_begin_closed thresh=19301.4µV
#   Rejected: {'amplitude': 0, 'kurtosis': 0, 'edge': 0, 'boundary': 2} (2/2)
#   RS_Beg_EC      :    0
# sub-20 ses-S1 rest_end_open thresh=12452.4µV
#   Rejected: {'amplitude': 0, 'kurtosis': 0, 'edge': 0, 'boundary': 2} (2/2)
#   RS_End_EO      :    0
# sub-20 ses-S1 rest_end_closed thresh=12800.7µV
#   Rejected: {'amplitude': 0, 'kurtosis': 0, 'edge': 0, 'boundary': 2} (2/2)
#   RS_End_EC      :    0
# ✓ sub-20 ses-S1: 1933 trials → sub-20_ses-S1_trials_event_locked.csv
#
# [59/63] sub-20 ses-S2
# sub-20 ses-S2 nback_0 thresh=9711.6µV
#   Rejected: {'amplitude': 0, 'kurtosis': 10, 'edge': 0, 'boundary': 3} (13/203)
#   zeroBACK       :  190
# sub-20 ses-S2 nback_1 thresh=9442.0µV
#   Rejected: {'amplitude': 0, 'kurtosis': 3, 'edge': 0, 'boundary': 3} (6/201)
#   oneBACK        :  195
# sub-20 ses-S2 nback_2 thresh=9871.7µV
#   Rejected: {'amplitude': 0, 'kurtosis': 14, 'edge': 1, 'boundary': 3} (18/206)
#   twoBACK        :  188
# sub-20 ses-S2 matb_easy thresh=9139.4µV
#   Rejected: {'amplitude': 0, 'kurtosis': 17, 'edge': 2} (19/199)
#   MATBeasy       :  180
# sub-20 ses-S2 matb_med thresh=10052.5µV
#   Rejected: {'amplitude': 0, 'kurtosis': 4, 'edge': 2} (6/199)
#   MATBmed        :  193
# sub-20 ses-S2 matb_diff thresh=10245.3µV
#   Rejected: {'amplitude': 0, 'kurtosis': 1, 'edge': 2} (3/199)
#   MATBdiff       :  196
# sub-20 ses-S2 pvt thresh=9273.7µV
#   Rejected: {'amplitude': 0, 'kurtosis': 0, 'edge': 0, 'boundary': 4} (4/273)
#   PVT            :  269
# sub-20 ses-S2 flanker thresh=10001.8µV
#   Rejected: {'amplitude': 0, 'kurtosis': 6, 'edge': 0, 'boundary': 5} (11/484)
#   Flanker        :  473
# sub-20 ses-S2 rest_begin_open thresh=9293.2µV
#   Rejected: {'amplitude': 0, 'kurtosis': 0, 'edge': 0, 'boundary': 2} (2/2)
#   RS_Beg_EO      :    0
# sub-20 ses-S2 rest_begin_closed thresh=9924.9µV
#   Rejected: {'amplitude': 0, 'kurtosis': 0, 'edge': 0, 'boundary': 2} (2/2)
#   RS_Beg_EC      :    0
# sub-20 ses-S2 rest_end_open thresh=8993.4µV
#   Rejected: {'amplitude': 0, 'kurtosis': 0, 'edge': 0, 'boundary': 2} (2/2)
#   RS_End_EO      :    0
# sub-20 ses-S2 rest_end_closed thresh=9291.2µV
#   Rejected: {'amplitude': 0, 'kurtosis': 0, 'edge': 0, 'boundary': 2} (2/2)
#   RS_End_EC      :    0
# ✓ sub-20 ses-S2: 1884 trials → sub-20_ses-S2_trials_event_locked.csv
#
# [60/63] sub-20 ses-S3
# sub-20 ses-S3 nback_0 thresh=11151.7µV
#   Rejected: {'amplitude': 34, 'kurtosis': 63, 'edge': 0, 'boundary': 3} (100/203)
#   zeroBACK       :  103
# sub-20 ses-S3 nback_1 thresh=12192.5µV
#   Rejected: {'amplitude': 78, 'kurtosis': 57, 'edge': 0, 'boundary': 3} (138/199)
#   oneBACK        :   61
# sub-20 ses-S3 nback_2 thresh=11567.6µV
#   Rejected: {'amplitude': 49, 'kurtosis': 68, 'edge': 0, 'boundary': 3} (120/206)
#   twoBACK        :   86
# sub-20 ses-S3 matb_easy thresh=9981.1µV
#   Rejected: {'amplitude': 49, 'kurtosis': 14, 'edge': 2} (65/199)
#   MATBeasy       :  134
# sub-20 ses-S3 matb_med thresh=13499.2µV
#   Rejected: {'amplitude': 37, 'kurtosis': 9, 'edge': 2} (48/199)
#   MATBmed        :  151
# sub-20 ses-S3 matb_diff thresh=13166.6µV
#   Rejected: {'amplitude': 47, 'kurtosis': 3, 'edge': 2} (52/199)
#   MATBdiff       :  147
# sub-20 ses-S3 pvt thresh=8986.0µV
#   Rejected: {'amplitude': 58, 'kurtosis': 60, 'edge': 0, 'boundary': 4} (122/273)
#   PVT            :  151
# sub-20 ses-S3 flanker thresh=13405.3µV
#   Rejected: {'amplitude': 94, 'kurtosis': 165, 'edge': 0, 'boundary': 5} (264/482)
#   Flanker        :  218
# sub-20 ses-S3 rest_begin_open thresh=6759.7µV
#   Rejected: {'amplitude': 0, 'kurtosis': 0, 'edge': 0, 'boundary': 2} (2/2)
#   RS_Beg_EO      :    0
# sub-20 ses-S3 rest_begin_closed thresh=6462.1µV
#   Rejected: {'amplitude': 0, 'kurtosis': 0, 'edge': 0, 'boundary': 2} (2/2)
#   RS_Beg_EC      :    0
# sub-20 ses-S3 rest_end_open thresh=13329.1µV
#   Rejected: {'amplitude': 0, 'kurtosis': 0, 'edge': 0, 'boundary': 2} (2/2)
#   RS_End_EO      :    0
# sub-20 ses-S3 rest_end_closed thresh=13030.8µV
#   Rejected: {'amplitude': 0, 'kurtosis': 0, 'edge': 0, 'boundary': 2} (2/2)
#   RS_End_EC      :    0
# ✓ sub-20 ses-S3: 1051 trials → sub-20_ses-S3_trials_event_locked.csv
#
# [61/63] sub-21 ses-S1
# sub-21 ses-S1 nback_0 thresh=13674.9µV
#   Rejected: {'amplitude': 0, 'kurtosis': 0, 'edge': 1, 'boundary': 2} (3/203)
#   zeroBACK       :  200
# sub-21 ses-S1 nback_1 thresh=13754.3µV
#   Rejected: {'amplitude': 0, 'kurtosis': 0, 'edge': 0, 'boundary': 3} (3/201)
#   oneBACK        :  198
# sub-21 ses-S1 nback_2 thresh=13078.1µV
#   Rejected: {'amplitude': 0, 'kurtosis': 0, 'edge': 0, 'boundary': 3} (3/200)
#   twoBACK        :  197
# sub-21 ses-S1 matb_easy thresh=14509.8µV
#   Rejected: {'amplitude': 0, 'kurtosis': 0, 'edge': 2} (2/199)
#   MATBeasy       :  197
# sub-21 ses-S1 matb_med thresh=16058.4µV
#   Rejected: {'amplitude': 0, 'kurtosis': 0, 'edge': 2} (2/199)
#   MATBmed        :  197
# sub-21 ses-S1 matb_diff thresh=14909.5µV
#   Rejected: {'amplitude': 0, 'kurtosis': 0, 'edge': 2} (2/199)
#   MATBdiff       :  197
# sub-21 ses-S1 pvt thresh=18290.9µV
#   Rejected: {'amplitude': 0, 'kurtosis': 0, 'edge': 0, 'boundary': 4} (4/273)
#   PVT            :  269
# sub-21 ses-S1 flanker thresh=13207.9µV
#   Rejected: {'amplitude': 0, 'kurtosis': 0, 'edge': 0, 'boundary': 5} (5/483)
#   Flanker        :  478
# sub-21 ses-S1 rest_begin_open thresh=18771.8µV
#   Rejected: {'amplitude': 0, 'kurtosis': 0, 'edge': 0, 'boundary': 2} (2/2)
#   RS_Beg_EO      :    0
# sub-21 ses-S1 rest_begin_closed thresh=19301.4µV
#   Rejected: {'amplitude': 0, 'kurtosis': 0, 'edge': 0, 'boundary': 2} (2/2)
#   RS_Beg_EC      :    0
# sub-21 ses-S1 rest_end_open thresh=12452.4µV
#   Rejected: {'amplitude': 0, 'kurtosis': 0, 'edge': 0, 'boundary': 2} (2/2)
#   RS_End_EO      :    0
# sub-21 ses-S1 rest_end_closed thresh=12800.7µV
#   Rejected: {'amplitude': 0, 'kurtosis': 0, 'edge': 0, 'boundary': 2} (2/2)
#   RS_End_EC      :    0
# ✓ sub-21 ses-S1: 1933 trials → sub-21_ses-S1_trials_event_locked.csv
#
# [62/63] sub-21 ses-S2
# sub-21 ses-S2 nback_0 thresh=9711.6µV
#   Rejected: {'amplitude': 0, 'kurtosis': 10, 'edge': 0, 'boundary': 3} (13/203)
#   zeroBACK       :  190
# sub-21 ses-S2 nback_1 thresh=9442.0µV
#   Rejected: {'amplitude': 0, 'kurtosis': 3, 'edge': 0, 'boundary': 3} (6/201)
#   oneBACK        :  195
# sub-21 ses-S2 nback_2 thresh=9871.7µV
#   Rejected: {'amplitude': 0, 'kurtosis': 14, 'edge': 1, 'boundary': 3} (18/206)
#   twoBACK        :  188
# sub-21 ses-S2 matb_easy thresh=9139.4µV
#   Rejected: {'amplitude': 0, 'kurtosis': 17, 'edge': 2} (19/199)
#   MATBeasy       :  180
# sub-21 ses-S2 matb_med thresh=10052.5µV
#   Rejected: {'amplitude': 0, 'kurtosis': 4, 'edge': 2} (6/199)
#   MATBmed        :  193
# sub-21 ses-S2 matb_diff thresh=10245.3µV
#   Rejected: {'amplitude': 0, 'kurtosis': 1, 'edge': 2} (3/199)
#   MATBdiff       :  196
# sub-21 ses-S2 pvt thresh=9273.7µV
#   Rejected: {'amplitude': 0, 'kurtosis': 0, 'edge': 0, 'boundary': 4} (4/273)
#   PVT            :  269
# sub-21 ses-S2 flanker thresh=10001.8µV
#   Rejected: {'amplitude': 0, 'kurtosis': 6, 'edge': 0, 'boundary': 5} (11/484)
#   Flanker        :  473
# sub-21 ses-S2 rest_begin_open thresh=9293.2µV
#   Rejected: {'amplitude': 0, 'kurtosis': 0, 'edge': 0, 'boundary': 2} (2/2)
#   RS_Beg_EO      :    0
# sub-21 ses-S2 rest_begin_closed thresh=9924.9µV
#   Rejected: {'amplitude': 0, 'kurtosis': 0, 'edge': 0, 'boundary': 2} (2/2)
#   RS_Beg_EC      :    0
# sub-21 ses-S2 rest_end_open thresh=8993.4µV
#   Rejected: {'amplitude': 0, 'kurtosis': 0, 'edge': 0, 'boundary': 2} (2/2)
#   RS_End_EO      :    0
# sub-21 ses-S2 rest_end_closed thresh=9291.2µV
#   Rejected: {'amplitude': 0, 'kurtosis': 0, 'edge': 0, 'boundary': 2} (2/2)
#   RS_End_EC      :    0
# ✓ sub-21 ses-S2: 1884 trials → sub-21_ses-S2_trials_event_locked.csv
#
# [63/63] sub-21 ses-S3
# sub-21 ses-S3 nback_0 thresh=11151.7µV
#   Rejected: {'amplitude': 34, 'kurtosis': 63, 'edge': 0, 'boundary': 3} (100/203)
#   zeroBACK       :  103
# sub-21 ses-S3 nback_1 thresh=12192.5µV
#   Rejected: {'amplitude': 78, 'kurtosis': 57, 'edge': 0, 'boundary': 3} (138/199)
#   oneBACK        :   61
# sub-21 ses-S3 nback_2 thresh=11567.6µV
#   Rejected: {'amplitude': 49, 'kurtosis': 68, 'edge': 0, 'boundary': 3} (120/206)
#   twoBACK        :   86
# sub-21 ses-S3 matb_easy thresh=9981.1µV
#   Rejected: {'amplitude': 49, 'kurtosis': 14, 'edge': 2} (65/199)
#   MATBeasy       :  134
# sub-21 ses-S3 matb_med thresh=13499.2µV
#   Rejected: {'amplitude': 37, 'kurtosis': 9, 'edge': 2} (48/199)
#   MATBmed        :  151
# sub-21 ses-S3 matb_diff thresh=13166.6µV
#   Rejected: {'amplitude': 47, 'kurtosis': 3, 'edge': 2} (52/199)
#   MATBdiff       :  147
# sub-21 ses-S3 pvt thresh=8986.0µV
#   Rejected: {'amplitude': 58, 'kurtosis': 60, 'edge': 0, 'boundary': 4} (122/273)
#   PVT            :  151
# sub-21 ses-S3 flanker thresh=13405.3µV
#   Rejected: {'amplitude': 94, 'kurtosis': 165, 'edge': 0, 'boundary': 5} (264/482)
#   Flanker        :  218
# sub-21 ses-S3 rest_begin_open thresh=6759.7µV
#   Rejected: {'amplitude': 0, 'kurtosis': 0, 'edge': 0, 'boundary': 2} (2/2)
#   RS_Beg_EO      :    0
# sub-21 ses-S3 rest_begin_closed thresh=6462.1µV
#   Rejected: {'amplitude': 0, 'kurtosis': 0, 'edge': 0, 'boundary': 2} (2/2)
#   RS_Beg_EC      :    0
# sub-21 ses-S3 rest_end_open thresh=13329.1µV
#   Rejected: {'amplitude': 0, 'kurtosis': 0, 'edge': 0, 'boundary': 2} (2/2)
#   RS_End_EO      :    0
# sub-21 ses-S3 rest_end_closed thresh=13030.8µV
#   Rejected: {'amplitude': 0, 'kurtosis': 0, 'edge': 0, 'boundary': 2} (2/2)
#   RS_End_EC      :    0
# ✓ sub-21 ses-S3: 1051 trials → sub-21_ses-S3_trials_event_locked.csv
#
# ================================================================================
# EXTRACTION COMPLETE: 60 sessions processed
# Total trials: 81966
# Output: C:\Users\rapol\Downloads\eeg_features_3ch_event_locked_optimized
# ================================================================================
